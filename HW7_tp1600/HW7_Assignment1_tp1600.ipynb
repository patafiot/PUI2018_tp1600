# %% [markdown]
# ## Assignment 1
# ### Tiffany Patafio
# ### Extension Deadline 10/27/18
#
# This notebook is designed to pratice with both geopandas and census data.  This is a simple spatial exploratory analysis of census data. The goal is to assess wheather the location of the [linkNYC](https://www.link.nyc/) access points is optimal to guarantee a more "democratic" access to the internet.
#
#
# ## THE CENSUS:
# make sure you do the assigned reading about the census. Census data are a national trasure! The census is a survey  designed to collect data on every person that lives in the USA every 10 years. The Census Bureau collects data, designes aggregation areas (the census blocks and tracts for example, which are designed for maximal homogeneity across all features). However, the Census Bureau does not only collect and aggregate data every 10 years, it also collects the America Community Survey every 5 years, and some more restricted survey on an annual bases. The 1 year survey data is what we will use: https://www.census.gov/services/index.html

# %%
import numpy as np
import pandas as pd
import requests
import pylab as pl
# %pylab inline
import geopandas as gpd
import shapely
import os
import sys
import urllib
import json
import io

from fiona.crs import from_epsg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 1. PUMA : Public Use Microdata Area
# Census geographies that are not specific political entities (i.e. states, counties etc) are designed for homogeneity so that aggregating the data over the whole area will leat to an estimat (mean or median for example) with minimal variance. Among these geographies are the _census tracts_, _census blocks_, and _Public Use Microdata Areas (PUMAs)_. PUMAs are geographical areas designed to aggregate census data. Each PUMA contains at least 100,000 people. PUMAs do not overlap, and are contained within a single state.
#
# ## 1.1 download the NYC  Public Use Microdata Areas (PUMA) geometry fron the NYC Open Data API and read it in with geopandas
#
# https://data.cityofnewyork.us/Housing-Development/Public-Use-Microdata-Areas-PUMA-/cwiz-gcty/data
#
# download it as a shape file. When you download a shapefile you actually download a zipped folder which contains the shape file and other files that are necessary to read the shape file in. You can do that with the urllib library in python 3 with the function
#
#         urllib.request.urlretrieve(url, "file.gz")
#
# then unpack the data into your PUIdata directory, then read it in with geopandas, reading in the shape file with the function
#
#         geopandas.GeoDataFrame.from_file(filename)

# %%
#commented as it is already run
#urllib.request.urlretrieve("https://data.cityofnewyork.us/api/geospatial/cwiz-gcty?method=export&format=Shapefile", "file.gz")

# %%
if os.getenv ('PUI2018') is None:
    print ("Must set env variable PUI2018")
if os.getenv ('PUIDATA') is None:
    print ("Must set env variable PUIDATA")
# Out:
# Must set env variable PUI2018

# %%
#commented as it is already moved
#!mv file.gz $PUIDATA

# %%
#!unzip $PUIDATA/file.gz -d $PUIDATA

# %%
pumashp=gpd.GeoDataFrame.from_file("/nfshome/tp1600/PUIdata/geo_export_8504fa16-6f0f-455f-a6fc-1437ff0abd25.shp")

# %% [markdown]
# PUMAs were first created for the 1990 Census. PUMAs are identified by a specific 4 numbers id. In the shapefile foung at data.cityofnewyork.us the id is named "puma" and it is in fact a 4 digits number. You can read it in as an integer (although of course it is a categorical variable inherently!). Often the PUMA id is found in conjunction with the 3 numbers state id, leading to a 7 numbers identification. The id for the State of NY is 036. See this link for more: https://www.census.gov/geo/reference/geoidentifiers.html

# %%
pumashp.head()
# Out:
#    puma    shape_area     shape_leng  \
# 0  3701  9.792852e+07   53227.144461
# 1  3702  1.889860e+08  106050.002302
# 2  3703  2.670137e+08  304071.257466
# 3  3704  1.062129e+08   47970.901277
# 4  4015  8.105438e+07   50007.415493
#
#                                             geometry
# 0  POLYGON ((-73.89641133483133 40.90450452082026...
# 1  POLYGON ((-73.8442314689986 40.86942035096838,...
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...
# 4  POLYGON ((-73.95374853778468 40.63858633758547...

# %%
pumashp.crs
# Out:
# {'init': 'epsg:4326'}

# %% [markdown]
# ## 1.2  plot the PUMA NYC regions
#
# you can use the geopandas function plot.
# What is the appropriate plot to just show the shape of the PUMA regions? A choropleth could be ok, but it is better to just draw the contours of the region, since we do not want to highlight some regions over others by color choices.
#
# (Note: a while ago I wrote a quick function that plots choropleths and maps of NYC specifically putting legends and colorbars in the empty spaces taking advantage of the shape of the city and you are welcome to use it: https://github.com/fedhere/choroplethNYC. BUT YOU DO NOT HAVE TO)
#
# If you want to learn how to install a package from within the notebook look here https://jakevdp.github.io/blog/2017/12/05/installing-python-packages-from-jupyter/
#
# Your map should look someting like:

# %%
naec = '+proj=eqdc +lat_0=40 +lon_0=-96 +lat_1=20 +lat_2=60 +x_0=0 +y_0=0 +datum=NAD83 +units=m +no_defs'
puma_naec=pumashp.to_crs(naec)

# %%
# using the built in plot function as pumashp.plot(pumashp....)
puma_naec.plot(figsize=(10,10), color="white", edgecolor="black", lw=2)
# using a choroplethNYC function that FBB wrote
#import choroplethNYC as cp
#cp.choroplethNYC(pumashp, column=None, color="white", edgecolor="black", lw=2);

# %% [markdown]
# ## Figure: The figure above shows a map of NYC as outlined by Public Use Microdata Areas NYC.

# %% [markdown]
# # 2. American Fact Finder data on percentage of houses with broadband internet access
#
# Download the table of data from 2016 for NYC: you want to obtain data on broadband access (percentage of households with broadband access) at the PUMA (Public Use Microdata Area) geographical area level.
#
# This may be tricky. But familiarizing with Census and American Commjunity Survey data is super important for urban science. Here you should use the API, but you should also practice interacting with the website:
#
# You  should read the datta in thgouth the API but also download the data manually and compare the two datasets.

# %% [markdown]
# ## 2.1 Get data with American Fact Finder (AFF) API:
# you can request an API key, although I think it is not necessary for this search (but it is good to practice). Obtain a key and save it into a python file. DO NOT UPLOAD THE FILE CONTAINING THE API KEY TO GITHUB. Keep your API keys private.

# %%
#reading in my api key saved in censusAPI.py as
#myAPI = 'XXXXXXXXXXXXXXX'
#from censusAPI import myAPI

# %% [markdown]
# If you need help with the API you can ask questions in this [Gitter channel](https://gitter.im/uscensusbureau/general) (I did myself to design this homework!)
# The internet subscription by household is data surveyd annually. You can find out what are the features that you can query through the API for the annually surveyed data at this url: https://api.census.gov/data/2016/acs/acs1/variables.json
#
# read it in as a jason file - you can do it with pandas (but it is slow). You can do it as I do below with the request package

# %%
#read in in the variables available. the info you need is in the 1year ACS data
url = "https://api.census.gov/data/2016/acs/acs1/variables.json"
resp = requests.request('GET', url)
aff1y = json.loads(resp.text)

# %%
aff1y
# Out:
# {'variables': {'B07404APR_002E': {'attributes': 'B07404APR_002M,B07404APR_002EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE) FOR RESIDENCE 1 YEAR AGO IN PUERTO RICO',
#    'group': 'B07404APR',
#    'label': 'Estimate!!Total living in area 1 year ago!!Same house',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24122_137E': {'attributes': 'B24122_137M,B24122_137EA',
#    'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED MALE POPULATION 16 YEARS AND OVER',
#    'group': 'B24122',
#    'label': 'Estimate!!Total!!Other teachers and instructors',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24121_235E': {'attributes': 'B24121_235M,B24121_235EA',
#    'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'B24121',
#    'label': 'Estimate!!Total!!First-line supervisors of housekeeping and janitorial workers',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B19131_098E': {'attributes': 'B19131_098M,B19131_098EA',
#    'concept': 'FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS BY FAMILY INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS)',
#    'group': 'B19131',
#    'label': 'Estimate!!Total!!Other family!!Female householder, no husband present!!No own children of the householder under 18 years!!$35,000 to $39,999',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B08101_045E': {'attributes': 'B08101_045M,B08101_045EA',
#    'concept': 'MEANS OF TRANSPORTATION TO WORK BY AGE',
#    'group': 'B08101',
#    'label': 'Estimate!!Total!!Taxicab, motorcycle, bicycle, or other means!!45 to 54 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24010D_060E': {'attributes': 'B24010D_060M,B24010D_060EA',
#    'concept': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER (ASIAN ALONE)',
#    'group': 'B24010D',
#    'label': 'Estimate!!Total!!Female!!Service occupations!!Food preparation and serving related occupations',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B06007_029E': {'attributes': 'B06007_029M,B06007_029EA',
#    'concept': 'PLACE OF BIRTH BY LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH IN THE UNITED STATES',
#    'group': 'B06007',
#    'label': 'Estimate!!Total!!Native; born outside the United States!!Speak Spanish!!Speak English less than "very well"',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C23002I_009E': {'attributes': 'C23002I_009M,C23002I_009EA',
#    'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER (HISPANIC OR LATINO)',
#    'group': 'C23002I',
#    'label': 'Estimate!!Total!!Male!!16 to 64 years!!Not in labor force',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B25075_013E': {'attributes': 'B25075_013M,B25075_013EA',
#    'concept': 'VALUE',
#    'group': 'B25075',
#    'label': 'Estimate!!Total!!$80,000 to $89,999',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B992521_002E': {'attributes': 'B992521_002EA',
#    'concept': 'ALLOCATION OF MORTGAGE STATUS',
#    'group': 'B992521',
#    'label': 'Estimate!!Total!!Allocated',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B23002B_039E': {'attributes': 'B23002B_039M,B23002B_039EA',
#    'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER (BLACK OR AFRICAN AMERICAN ALONE)',
#    'group': 'B23002B',
#    'label': 'Estimate!!Total!!Male!!70 years and over!!In labor force!!Unemployed',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24126_235E': {'attributes': 'B24126_235M,B24126_235EA',
#    'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#    'group': 'B24126',
#    'label': 'Estimate!!Total!!First-line supervisors of housekeeping and janitorial workers',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B17010H_018E': {'attributes': 'B17010H_018M,B17010H_018EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY PRESENCE OF RELATED CHILDREN UNDER 18 YEARS BY AGE OF RELATED CHILDREN (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#    'group': 'B17010H',
#    'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Other family!!Female householder, no husband present!!With related children of the householder under 18 years!!Under 5 years only',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B07403_014E': {'attributes': 'B07403_014M,B07403_014EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES',
#    'group': 'B07403',
#    'label': 'Estimate!!Total living in area 1 year ago!!Moved to different state!!Male',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C06001PR_024E': {'attributes': 'C06001PR_024M,C06001PR_024EA',
#    'concept': 'PLACE OF BIRTH BY AGE IN PUERTO RICO',
#    'group': 'C06001PR',
#    'label': 'Estimate!!Total!!Born in the United States!!45 to 54 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C17003_007E': {'attributes': 'C17003_007M,C17003_007EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF INDIVIDUALS BY EDUCATIONAL ATTAINMENT',
#    'group': 'C17003',
#    'label': 'Estimate!!Total!!Income in the past 12 months at or above poverty level',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B27006_041E': {'attributes': 'B27006_041M,B27006_041EA',
#    'concept': 'MEDICARE COVERAGE BY SEX BY AGE',
#    'group': 'B27006',
#    'label': 'Estimate!!Total!!Female!!25 to 34 years!!With Medicare coverage',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24121_198E': {'attributes': 'B24121_198M,B24121_198EA',
#    'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'B24121',
#    'label': 'Estimate!!Total!!Medical assistants',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C08111_010E': {'attributes': 'C08111_010M,C08111_010EA',
#    'concept': 'MEANS OF TRANSPORTATION TO WORK BY CITIZENSHIP STATUS',
#    'group': 'C08111',
#    'label': 'Estimate!!Total!!Car, truck, or van - drove alone!!Foreign-born!!Not a U.S. citizen',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B07009PR_022E': {'attributes': 'B07009PR_022M,B07009PR_022EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN PUERTO RICO',
#    'group': 'B07009PR',
#    'label': "Estimate!!Total!!Moved from different municipio!!Some college or associate's degree",
#    'limit': 0,
#    'predicateType': 'int'},
#   'B16009_021E': {'attributes': 'B16009_021M,B16009_021EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY AGE BY LANGUAGE SPOKEN AT HOME FOR THE POPULATION 5 YEARS AND OVER',
#    'group': 'B16009',
#    'label': 'Estimate!!Total!!Income in the past 12 months at or above poverty level!!5 to 17 years!!Speak other languages',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B07204_012E': {'attributes': 'B07204_012M,B07204_012EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--STATE, COUNTY AND PLACE LEVEL IN THE UNITED STATES',
#    'group': 'B07204',
#    'label': 'Estimate!!Total!!Different house in United States 1 year ago!!Elsewhere!!Different county!!Different state!!Northeast',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C08532_001E': {'attributes': 'C08532_001M,C08532_001EA',
#    'concept': 'MEANS OF TRANSPORTATION TO WORK BY TIME ARRIVING AT WORK FROM HOME FOR WORKPLACE GEOGRAPHY',
#    'group': 'C08532',
#    'label': 'Estimate!!Total',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C15002H_005E': {'attributes': 'C15002H_005M,C15002H_005EA',
#    'concept': 'SEX BY EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER (WHITE ALONE, NOT HISPANIC OR LATINO)',
#    'group': 'C15002H',
#    'label': "Estimate!!Total!!Male!!Some college or associate's degree",
#    'limit': 0,
#    'predicateType': 'int'},
#   'B17012_031E': {'attributes': 'B17012_031M,B17012_031EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY NUMBER OF RELATED CHILDREN UNDER 18 YEARS',
#    'group': 'B17012',
#    'label': 'Estimate!!Total!!Income in the past 12 months at or above poverty level!!Other families!!Female householder, no husband present',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24123_016E': {'attributes': 'B24123_016M,B24123_016EA',
#    'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#    'group': 'B24123',
#    'label': 'Estimate!!Total!!Transportation, storage, and distribution managers',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B08122_006E': {'attributes': 'B08122_006M,B08122_006EA',
#    'concept': 'MEANS OF TRANSPORTATION TO WORK BY POVERTY STATUS IN THE PAST 12 MONTHS',
#    'group': 'B08122',
#    'label': 'Estimate!!Total!!Car, truck, or van - drove alone!!Below 100 percent of the poverty level',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B17010I_041E': {'attributes': 'B17010I_041M,B17010I_041EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY PRESENCE OF RELATED CHILDREN UNDER 18 YEARS BY AGE OF RELATED CHILDREN (HISPANIC OR LATINO)',
#    'group': 'B17010I',
#    'label': 'Estimate!!Total!!Income in the past 12 months at or above poverty level!!Other family!!Female householder, no husband present!!No related children of the householder under 18 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B08412_030E': {'attributes': 'B08412_030M,B08412_030EA',
#    'concept': 'SEX OF WORKERS BY TRAVEL TIME TO WORK FOR WORKPLACE GEOGRAPHY',
#    'group': 'B08412',
#    'label': 'Estimate!!Total!!Female!!10 to 14 minutes',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B27017_068E': {'attributes': 'B27017_068M,B27017_068EA',
#    'concept': 'PRIVATE HEALTH INSURANCE  BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#    'group': 'B27017',
#    'label': 'Estimate!!Total!!2.50 to 2.99 of poverty threshold!!18 to 64 years!!No private health insurance',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B08119_053E': {'attributes': 'B08119_053M,B08119_053EA',
#    'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS)",
#    'group': 'B08119',
#    'label': 'Estimate!!Total!!Taxicab, motorcycle, bicycle, or other means!!$65,000 to $74,999',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B23001_124E': {'attributes': 'B23001_124M,B23001_124EA',
#    'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER',
#    'group': 'B23001',
#    'label': 'Estimate!!Total!!Female!!35 to 44 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B19037H_068E': {'attributes': 'B19037H_068M,B19037H_068EA',
#    'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#    'group': 'B19037H',
#    'label': 'Estimate!!Total!!Householder 65 years and over!!$150,000 to $199,999',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B07009_029E': {'attributes': 'B07009_029M,B07009_029EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#    'group': 'B07009',
#    'label': "Estimate!!Total!!Moved from different state!!Bachelor's degree",
#    'limit': 0,
#    'predicateType': 'int'},
#   'B08534_019E': {'attributes': 'B08534_019M,B08534_019EA',
#    'concept': 'MEANS OF TRANSPORTATION TO WORK BY TRAVEL TIME TO WORK FOR WORKPLACE GEOGRAPHY',
#    'group': 'B08534',
#    'label': 'Estimate!!Total!!Car, truck, or van!!45 to 59 minutes',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24010_113E': {'attributes': 'B24010_113M,B24010_113EA',
#    'concept': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'B24010',
#    'label': 'Estimate!!Total!!Male!!Natural resources, construction, and maintenance occupations!!Farming, fishing, and forestry occupations',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B14004_022E': {'attributes': 'B14004_022M,B14004_022EA',
#    'concept': 'SEX BY COLLEGE OR GRADUATE SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 15 YEARS AND OVER',
#    'group': 'B14004',
#    'label': 'Estimate!!Total!!Female!!Enrolled in public college or graduate school!!25 to 34 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24010F_024E': {'attributes': 'B24010F_024M,B24010F_024EA',
#    'concept': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER (SOME OTHER RACE ALONE)',
#    'group': 'B24010F',
#    'label': 'Estimate!!Total!!Male!!Service occupations!!Food preparation and serving related occupations',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B01001G_015E': {'attributes': 'B01001G_015M,B01001G_015EA',
#    'concept': 'SEX BY AGE (TWO OR MORE RACES)',
#    'group': 'B01001G',
#    'label': 'Estimate!!Total!!Male!!75 to 84 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24010_161E': {'attributes': 'B24010_161M,B24010_161EA',
#    'concept': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'B24010',
#    'label': 'Estimate!!Total!!Female!!Management, business, science, and arts occupations!!Management, business, and financial occupations!!Management occupations!!Operations specialties managers except financial managers and human resources managers',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B17001E_012E': {'attributes': 'B17001E_012M,B17001E_012EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#    'group': 'B17001E',
#    'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!35 to 44 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B19037F_036E': {'attributes': 'B19037F_036M,B19037F_036EA',
#    'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (SOME OTHER RACE ALONE HOUSEHOLDER)',
#    'group': 'B19037F',
#    'label': 'Estimate!!Total!!Householder 45 to 64 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B27001I_005E': {'attributes': 'B27001I_005M,B27001I_005EA',
#    'concept': 'HEALTH INSURANCE COVERAGE STATUS BY AGE (HISPANIC OR LATINO)',
#    'group': 'B27001I',
#    'label': 'Estimate!!Total!!6 to 17 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24122_164E': {'attributes': 'B24122_164M,B24122_164EA',
#    'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED MALE POPULATION 16 YEARS AND OVER',
#    'group': 'B24122',
#    'label': 'Estimate!!Total!!Optometrists',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C21001G_012E': {'attributes': 'C21001G_012M,C21001G_012EA',
#    'concept': 'SEX BY AGE BY VETERAN STATUS FOR THE CIVILIAN POPULATION 18 YEARS AND OVER (TWO OR MORE RACES)',
#    'group': 'C21001G',
#    'label': 'Estimate!!Total!!Female!!18 to 64 years!!Nonveteran',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C06001PR_004E': {'attributes': 'C06001PR_004M,C06001PR_004EA',
#    'concept': 'PLACE OF BIRTH BY AGE IN PUERTO RICO',
#    'group': 'C06001PR',
#    'label': 'Estimate!!Total!!18 to 24 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B10063_006E': {'attributes': 'B10063_006M,B10063_006EA',
#    'concept': 'HOUSEHOLDS WITH GRANDPARENTS LIVING WITH OWN GRANDCHILDREN UNDER 18 YEARS BY RESPONSIBILITY FOR OWN GRANDCHILDREN AND PRESENCE OF PARENT OF GRANDCHILDREN',
#    'group': 'B10063',
#    'label': 'Estimate!!Total!!Household with grandparents living with grandchildren!!Household with grandparent not responsible for own grandchildren under 18 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B27006_016E': {'attributes': 'B27006_016M,B27006_016EA',
#    'concept': 'MEDICARE COVERAGE BY SEX BY AGE',
#    'group': 'B27006',
#    'label': 'Estimate!!Total!!Male!!35 to 44 years!!With Medicare coverage',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C15002D_008E': {'attributes': 'C15002D_008M,C15002D_008EA',
#    'concept': 'SEX BY EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER (ASIAN ALONE)',
#    'group': 'C15002D',
#    'label': 'Estimate!!Total!!Female!!Less than high school diploma',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24123_131E': {'attributes': 'B24123_131M,B24123_131EA',
#    'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#    'group': 'B24123',
#    'label': 'Estimate!!Total!!Miscellaneous legal support workers',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B07203_005E': {'attributes': 'B07203_005M,B07203_005EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--NOT METROPOLITAN OR MICROPOLITAN STATISTICAL AREA LEVEL IN THE UNITED STATES',
#    'group': 'B07203',
#    'label': 'Estimate!!Total!!Different house in United States 1 year ago!!Metropolitan Statistical Area!!Moved from principal city',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B16010_051E': {'attributes': 'B16010_051M,B16010_051EA',
#    'concept': 'EDUCATIONAL ATTAINMENT AND EMPLOYMENT STATUS BY LANGUAGE SPOKEN AT HOME FOR THE POPULATION 25 YEARS AND OVER',
#    'group': 'B16010',
#    'label': "Estimate!!Total!!Bachelor's degree or higher!!Not in labor force!!Speak other Indo-European languages",
#    'limit': 0,
#    'predicateType': 'int'},
#   'B25038_015E': {'attributes': 'B25038_015M,B25038_015EA',
#    'concept': 'TENURE BY YEAR HOUSEHOLDER MOVED INTO UNIT',
#    'group': 'B25038',
#    'label': 'Estimate!!Total!!Renter occupied!!Moved in 1979 or earlier',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C17001E_012E': {'attributes': 'C17001E_012M,C17001E_012EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#    'group': 'C17001E',
#    'label': 'Estimate!!Total!!Income in the past 12 months at or above poverty level!!Male',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B12006_011E': {'attributes': 'B12006_011M,B12006_011EA',
#    'concept': 'MARITAL STATUS BY SEX BY LABOR FORCE PARTICIPATION',
#    'group': 'B12006',
#    'label': 'Estimate!!Total!!Never married!!Female!!In labor force!!Unemployed',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B21001E_030E': {'attributes': 'B21001E_030M,B21001E_030EA',
#    'concept': 'SEX BY AGE BY VETERAN STATUS FOR THE CIVILIAN POPULATION 18 YEARS AND OVER (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#    'group': 'B21001E',
#    'label': 'Estimate!!Total!!Female!!65 to 74 years!!Nonveteran',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24121_201E': {'attributes': 'B24121_201M,B24121_201EA',
#    'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'B24121',
#    'label': 'Estimate!!Total!!Veterinary assistants and laboratory animal caretakers',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B07001PR_076E': {'attributes': 'B07001PR_076M,B07001PR_076EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#    'group': 'B07001PR',
#    'label': 'Estimate!!Total!!Moved from the United States!!55 to 59 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B17003_002E': {'attributes': 'B17003_002M,B17003_002EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF INDIVIDUALS BY SEX BY EDUCATIONAL ATTAINMENT',
#    'group': 'B17003',
#    'label': 'Estimate!!Total!!Income in the past 12 months below poverty level',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B02018_015E': {'attributes': 'B02018_015M,B02018_015EA',
#    'concept': 'ASIAN ALONE OR IN ANY COMBINATION BY SELECTED GROUPS',
#    'group': 'B02018',
#    'label': 'Estimate!!Total Groups Tallied!!Mongolian',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B19037B_014E': {'attributes': 'B19037B_014M,B19037B_014EA',
#    'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#    'group': 'B19037B',
#    'label': 'Estimate!!Total!!Householder under 25 years!!$75,000 to $99,999',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B25129_010E': {'attributes': 'B25129_010M,B25129_010EA',
#    'concept': 'TENURE BY YEAR HOUSEHOLDER MOVED INTO UNIT BY UNITS IN STRUCTURE',
#    'group': 'B25129',
#    'label': 'Estimate!!Total!!Owner occupied!!Moved in 2000 to 2009',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B10053_003E': {'attributes': 'B10053_003M,B10053_003EA',
#    'concept': 'NATIVITY BY GRANDPARENTS RESPONSIBLE FOR OWN GRANDCHILDREN UNDER 18 YEARS BY AGE OF GRANDPARENT',
#    'group': 'B10053',
#    'label': 'Estimate!!Total!!Native!!Grandparent responsible for own grandchildren under 18 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B23001_021E': {'attributes': 'B23001_021M,B23001_021EA',
#    'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER',
#    'group': 'B23001',
#    'label': 'Estimate!!Total!!Male!!22 to 24 years!!In labor force!!Civilian!!Employed',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B07009PR_003E': {'attributes': 'B07009PR_003M,B07009PR_003EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN PUERTO RICO',
#    'group': 'B07009PR',
#    'label': 'Estimate!!Total!!High school graduate (includes equivalency)',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B19216_013E': {'attributes': 'B19216_013M,B19216_013EA',
#    'concept': 'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#    'group': 'B19216',
#    'label': 'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2016 inflation-adjusted dollars)!!Female householder (dollars)!!Not living alone (dollars)',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B04004_011E': {'attributes': 'B04004_011M,B04004_011EA',
#    'concept': 'PEOPLE REPORTING SINGLE ANCESTRY',
#    'group': 'B04004',
#    'label': 'Estimate!!Total!!Arab!!Moroccan',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C06001PR_014E': {'attributes': 'C06001PR_014M,C06001PR_014EA',
#    'concept': 'PLACE OF BIRTH BY AGE IN PUERTO RICO',
#    'group': 'C06001PR',
#    'label': 'Estimate!!Total!!Born in Puerto Rico!!25 to 44 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B23002C_067E': {'attributes': 'B23002C_067M,B23002C_067EA',
#    'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#    'group': 'B23002C',
#    'label': 'Estimate!!Total!!Female!!55 to 64 years!!In labor force!!Civilian!!Employed',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24123_481E': {'attributes': 'B24123_481M,B24123_481EA',
#    'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#    'group': 'B24123',
#    'label': 'Estimate!!Total!!Semiconductor processors',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B17010B_014E': {'attributes': 'B17010B_014M,B17010B_014EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY PRESENCE OF RELATED CHILDREN UNDER 18 YEARS BY AGE OF RELATED CHILDREN (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#    'group': 'B17010B',
#    'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Other family!!Male householder, no wife present!!With related children of the householder under 18 years!!5 to 17 years only',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C07001_058E': {'attributes': 'C07001_058M,C07001_058EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#    'group': 'C07001',
#    'label': 'Estimate!!Total!!Moved from abroad!!55 to 64 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B25036_018E': {'attributes': 'B25036_018M,B25036_018EA',
#    'concept': 'TENURE BY YEAR STRUCTURE BUILT',
#    'group': 'B25036',
#    'label': 'Estimate!!Total!!Renter occupied!!Built 1980 to 1989',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B19130_014E': {'attributes': 'B19130_014M,B19130_014EA',
#    'concept': 'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#    'group': 'B19130',
#    'label': 'Estimate!!Aggregate family income in the past 12 months (in 2016 inflation-adjusted dollars)!!Other family (dollars)!!Male householder, no wife present (dollars)!!Householder 25 to 34 years (dollars)',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C24040_007E': {'attributes': 'C24040_007M,C24040_007EA',
#    'concept': 'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'C24040',
#    'label': 'Estimate!!Total!!Male!!Manufacturing',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B04005_096E': {'attributes': 'B04005_096M,B04005_096EA',
#    'concept': 'PEOPLE REPORTING MULTIPLE ANCESTRY',
#    'group': 'B04005',
#    'label': 'Estimate!!Total!!West Indian (except Hispanic groups)!!Barbadian',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24030_168E': {'attributes': 'B24030_168M,B24030_168EA',
#    'concept': 'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'B24030',
#    'label': 'Estimate!!Total!!Female!!Retail trade!!Retail florists',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24124_479E': {'attributes': 'B24124_479M,B24124_479EA',
#    'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'B24124',
#    'label': 'Estimate!!Total!!Painting workers',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C23002H_026E': {'attributes': 'C23002H_026M,C23002H_026EA',
#    'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE, NOT HISPANIC OR LATINO)',
#    'group': 'C23002H',
#    'label': 'Estimate!!Total!!Female!!65 years and over!!In labor force!!Unemployed',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B08534_095E': {'attributes': 'B08534_095M,B08534_095EA',
#    'concept': 'MEANS OF TRANSPORTATION TO WORK BY TRAVEL TIME TO WORK FOR WORKPLACE GEOGRAPHY',
#    'group': 'B08534',
#    'label': 'Estimate!!Total!!Public transportation (excluding taxicab)!!Railroad or ferryboat!!20 to 24 minutes',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B07204_006E': {'attributes': 'B07204_006M,B07204_006EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--STATE, COUNTY AND PLACE LEVEL IN THE UNITED STATES',
#    'group': 'B07204',
#    'label': 'Estimate!!Total!!Different house in United States 1 year ago!!Same city or town!!Different county (same state)',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B18131_070E': {'attributes': 'B18131_070M,B18131_070EA',
#    'concept': 'AGE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY DISABILITY STATUS AND TYPE',
#    'group': 'B18131',
#    'label': 'Estimate!!Total!!18 years and over!!Under .50',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B28010_007E': {'attributes': 'B28010_007M,B28010_007EA',
#    'concept': 'COMPUTERS IN HOUSEHOLD',
#    'group': 'B28010',
#    'label': 'Estimate!!Total!!No Computer',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B07203PR_004E': {'attributes': 'B07203PR_004M,B07203PR_004EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--NOT METROPOLITAN OR MICROPOLITAN STATISTICAL AREA LEVEL IN PUERTO RICO',
#    'group': 'B07203PR',
#    'label': 'Estimate!!Total!!Different house in Puerto Rico 1 year ago!!Metropolitan Statistical Area',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B27013_011E': {'attributes': 'B27013_011M,B27013_011EA',
#    'concept': 'PRIVATE HEALTH INSURANCE BY WORK EXPERIENCE BY SEX BY AGE',
#    'group': 'B27013',
#    'label': 'Estimate!!Total!!Worked full-time, year-round!!Female!!18 to 64 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B23002F_048E': {'attributes': 'B23002F_048M,B23002F_048EA',
#    'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER (SOME OTHER RACE ALONE)',
#    'group': 'B23002F',
#    'label': 'Estimate!!Total!!Female!!16 to 19 years!!Not in labor force',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B20005H_068E': {'attributes': 'B20005H_068M,B20005H_068EA',
#    'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE, NOT HISPANIC OR LATINO)',
#    'group': 'B20005H',
#    'label': 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With earnings!!$50,000 to $54,999',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B21001B_029E': {'attributes': 'B21001B_029M,B21001B_029EA',
#    'concept': 'SEX BY AGE BY VETERAN STATUS FOR THE CIVILIAN POPULATION 18 YEARS AND OVER (BLACK OR AFRICAN AMERICAN ALONE)',
#    'group': 'B21001B',
#    'label': 'Estimate!!Total!!Female!!65 to 74 years!!Veteran',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B12006_049E': {'attributes': 'B12006_049M,B12006_049EA',
#    'concept': 'MARITAL STATUS BY SEX BY LABOR FORCE PARTICIPATION',
#    'group': 'B12006',
#    'label': 'Estimate!!Total!!Divorced!!Male!!In labor force!!Employed or in Armed Forces',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24010_090E': {'attributes': 'B24010_090M,B24010_090EA',
#    'concept': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'B24010',
#    'label': 'Estimate!!Total!!Male!!Service occupations!!Personal care and service occupations!!Baggage porters and concierges, and tour and travel guides',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B07201PR_019E': {'attributes': 'B07201PR_019M,B07201PR_019EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--METROPOLITAN STATISTICAL AREA LEVEL IN PUERTO RICO',
#    'group': 'B07201PR',
#    'label': 'Estimate!!Total!!United States 1 year ago!!Micropolitan Statistical Area!!Moved from principal city',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C05006_028E': {'attributes': 'C05006_028M,C05006_028EA',
#    'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION',
#    'group': 'C05006',
#    'label': 'Estimate!!Total!!Asia!!Eastern Asia!!Korea',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B19216_003E': {'attributes': 'B19216_003M,B19216_003EA',
#    'concept': 'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#    'group': 'B19216',
#    'label': 'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2016 inflation-adjusted dollars)!!Male householder (dollars)!!Living alone (dollars)',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C24010_028E': {'attributes': 'C24010_028M,C24010_028EA',
#    'concept': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'C24010',
#    'label': 'Estimate!!Total!!Male!!Sales and office occupations!!Sales and related occupations',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C23002I_023E': {'attributes': 'C23002I_023M,C23002I_023EA',
#    'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER (HISPANIC OR LATINO)',
#    'group': 'C23002I',
#    'label': 'Estimate!!Total!!Female!!65 years and over',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24060_156E': {'attributes': 'B24060_156M,B24060_156EA',
#    'concept': 'OCCUPATION BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'B24060',
#    'label': 'Estimate!!Total!!Local, state, and federal government workers!!Management, business, science, and arts occupations!!Education, legal, community service, arts, and media occupations!!Legal occupations',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C17009_005E': {'attributes': 'C17009_005M,C17009_005EA',
#    'concept': 'POVERTY STATUS BY WORK EXPERIENCE OF UNRELATED INDIVIDUALS',
#    'group': 'C17009',
#    'label': 'Estimate!!Total!!Income in the past 12 months below the poverty level!!Did not work',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B27011_004E': {'attributes': 'B27011_004M,B27011_004EA',
#    'concept': 'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY EMPLOYMENT STATUS BY AGE',
#    'group': 'B27011',
#    'label': 'Estimate!!Total!!In labor force!!Employed!!18 to 64 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B09020_019E': {'attributes': 'B09020_019M,B09020_019EA',
#    'concept': 'RELATIONSHIP BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) FOR THE POPULATION 65 YEARS AND OVER',
#    'group': 'B09020',
#    'label': 'Estimate!!Total!!In households!!In nonfamily households!!Householder!!Female!!Not living alone',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24125_035E': {'attributes': 'B24125_035M,B24125_035EA',
#    'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED MALE POPULATION 16 YEARS AND OVER',
#    'group': 'B24125',
#    'label': 'Estimate!!Total!!Purchasing agents, except wholesale, retail, and farm products',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B23006_008E': {'attributes': 'B23006_008M,B23006_008EA',
#    'concept': 'EDUCATIONAL ATTAINMENT BY EMPLOYMENT STATUS FOR THE POPULATION 25 TO 64 YEARS',
#    'group': 'B23006',
#    'label': 'Estimate!!Total!!Less than high school graduate!!Not in labor force',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C06010PR_030E': {'attributes': 'C06010PR_030M,C06010PR_030EA',
#    'concept': 'PLACE OF BIRTH BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) IN PUERTO RICO',
#    'group': 'C06010PR',
#    'label': 'Estimate!!Total!!Born in the United States!!With income!!$35,000 to $49,999',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B23027_024E': {'attributes': 'B23027_024M,B23027_024EA',
#    'concept': 'FULL-TIME, YEAR-ROUND WORK STATUS IN THE PAST 12 MONTHS BY AGE FOR THE POPULATION 16 YEARS AND OVER',
#    'group': 'B23027',
#    'label': 'Estimate!!Total!!55 to 64 years!!Worked in the past 12 months!!Worked full-time, year-round',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24125_071E': {'attributes': 'B24125_071M,B24125_071EA',
#    'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED MALE POPULATION 16 YEARS AND OVER',
#    'group': 'B24125',
#    'label': 'Estimate!!Total!!Actuaries',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B18135_028E': {'attributes': 'B18135_028M,B18135_028EA',
#    'concept': 'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#    'group': 'B18135',
#    'label': 'Estimate!!Total!!65 years and over!!With a disability!!With health insurance coverage!!With public health coverage',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B08536_011E': {'attributes': 'B08536_011M,B08536_011EA',
#    'concept': 'AGGREGATE TRAVEL TIME TO WORK (IN MINUTES) OF WORKERS BY MEANS OF TRANSPORTATION TO WORK FOR WORKPLACE GEOGRAPHY',
#    'group': 'B08536',
#    'label': 'Estimate!!Aggregate travel time to work (in minutes)!!Walked',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C08534_003E': {'attributes': 'C08534_003M,C08534_003EA',
#    'concept': 'MEANS OF TRANSPORTATION TO WORK BY TRAVEL TIME TO WORK FOR WORKPLACE GEOGRAPHY',
#    'group': 'C08534',
#    'label': 'Estimate!!Total!!10 to 14 minutes',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B20005_090E': {'attributes': 'B20005_090M,B20005_090EA',
#    'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#    'group': 'B20005',
#    'label': 'Estimate!!Total!!Female!!Other!!With earnings!!$45,000 to $49,999',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B25121_079E': {'attributes': 'B25121_079M,B25121_079EA',
#    'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) BY VALUE',
#    'group': 'B25121',
#    'label': 'Estimate!!Total!!Household income the past 12 months (in 2016 inflation-adjusted dollars)!!$75,000 to $99,999!!Value $10,000 to $19,999',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B17001G_004E': {'attributes': 'B17001G_004M,B17001G_004EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#    'group': 'B17001G',
#    'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!Under 5 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24123_115E': {'attributes': 'B24123_115M,B24123_115EA',
#    'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#    'group': 'B24123',
#    'label': 'Estimate!!Total!!Geological and petroleum technicians',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B08134_063E': {'attributes': 'B08134_063M,B08134_063EA',
#    'concept': 'MEANS OF TRANSPORTATION TO WORK BY TRAVEL TIME TO WORK',
#    'group': 'B08134',
#    'label': 'Estimate!!Total!!Public transportation (excluding taxicab)!!10 to 14 minutes',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C23004_002E': {'attributes': 'C23004_002M,C23004_002EA',
#    'concept': 'WORK STATUS IN THE PAST 12 MONTHS BY EMPLOYMENT STATUS FOR THE CIVILIAN POPULATION 65 YEARS AND OVER',
#    'group': 'C23004',
#    'label': 'Estimate!!Total!!Worked in the past 12 months',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B07409PR_007E': {'attributes': 'B07409PR_007M,B07409PR_007EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR RESIDENCE 1 YEAR AGO IN PUERTO RICO',
#    'group': 'B07409PR',
#    'label': 'Estimate!!Total living in area 1 year ago!!Same house',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24050_047E': {'attributes': 'B24050_047M,B24050_047EA',
#    'concept': 'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'B24050',
#    'label': 'Estimate!!Total!!Management, business, science, and arts occupations!!Educational services, and health care and social assistance',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B27015_009E': {'attributes': 'B27015_009M,B27015_009EA',
#    'concept': 'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS)',
#    'group': 'B27015',
#    'label': 'Estimate!!Total!!$25,000 to $49,999!!With health insurance coverage!!With private health insurance',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B08130_007E': {'attributes': 'B08130_007M,B08130_007EA',
#    'concept': 'MEANS OF TRANSPORTATION TO WORK BY PLACE OF WORK--STATE AND COUNTY LEVEL',
#    'group': 'B08130',
#    'label': 'Estimate!!Total!!Car, truck, or van - drove alone!!Worked in state of residence',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B07101_020E': {'attributes': 'B07101_020M,B07101_020EA',
#    'concept': 'MOVERS BETWEEN REGIONS IN THE UNITED STATES',
#    'group': 'B07101',
#    'label': 'Estimate!!Total!!Current residence; Northeast!!Movers to different state!!Residence 1 year ago!!West',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C17006_001E': {'attributes': 'C17006_001M,C17006_001EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF RELATED CHILDREN UNDER 18 YEARS BY FAMILY TYPE',
#    'group': 'C17006',
#    'label': 'Estimate!!Total',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C17001B_012E': {'attributes': 'C17001B_012M,C17001B_012EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#    'group': 'C17001B',
#    'label': 'Estimate!!Total!!Income in the past 12 months at or above poverty level!!Male',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B18103_021E': {'attributes': 'B18103_021M,B18103_021EA',
#    'concept': 'SEX BY AGE BY VISION DIFFICULTY',
#    'group': 'B18103',
#    'label': 'Estimate!!Total!!Female',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C24040_020E': {'attributes': 'C24040_020M,C24040_020EA',
#    'concept': 'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'C24040',
#    'label': 'Estimate!!Total!!Male!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B16005C_006E': {'attributes': 'B16005C_006M,B16005C_006EA',
#    'concept': 'NATIVITY BY LANGUAGE SPOKEN AT HOME BY ABILITY TO SPEAK ENGLISH FOR THE POPULATION 5 YEARS AND OVER (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#    'group': 'B16005C',
#    'label': 'Estimate!!Total!!Native!!Speak another language!!Speak English less than "very well"',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24010H_010E': {'attributes': 'B24010H_010M,B24010H_010EA',
#    'concept': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER (WHITE ALONE, NOT HISPANIC OR LATINO)',
#    'group': 'B24010H',
#    'label': 'Estimate!!Total!!Male!!Management, business, science, and arts occupations!!Computer, engineering, and science occupations!!Life, physical, and social science occupations',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B25106_002E': {'attributes': 'B25106_002M,B25106_002EA',
#    'concept': 'TENURE BY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS',
#    'group': 'B25106',
#    'label': 'Estimate!!Total!!Owner-occupied housing units',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24125_043E': {'attributes': 'B24125_043M,B24125_043EA',
#    'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED MALE POPULATION 16 YEARS AND OVER',
#    'group': 'B24125',
#    'label': 'Estimate!!Total!!Management analysts',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B19216_005E': {'attributes': 'B19216_005M,B19216_005EA',
#    'concept': 'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#    'group': 'B19216',
#    'label': 'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2016 inflation-adjusted dollars)!!Male householder (dollars)!!Living alone (dollars)!!Householder 65 years and over (dollars)',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B08537_013E': {'attributes': 'B08537_013M,B08537_013EA',
#    'concept': 'MEANS OF TRANSPORTATION TO WORK BY TENURE FOR WORKPLACE GEOGRAPHY',
#    'group': 'B08537',
#    'label': 'Estimate!!Total!!Walked',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B27004_025E': {'attributes': 'B27004_025M,B27004_025EA',
#    'concept': 'EMPLOYER-BASED HEALTH INSURANCE  BY SEX BY AGE',
#    'group': 'B27004',
#    'label': 'Estimate!!Total!!Male!!65 to 74 years!!With employer-based health insurance',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C27006_010E': {'attributes': 'C27006_010M,C27006_010EA',
#    'concept': 'MEDICARE COVERAGE BY SEX BY AGE',
#    'group': 'C27006',
#    'label': 'Estimate!!Total!!Male!!65 years and over!!With Medicare coverage',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B07407PR_001E': {'attributes': 'B07407PR_001M,B07407PR_001EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR RESIDENCE 1 YEAR AGO IN PUERTO RICO',
#    'group': 'B07407PR',
#    'label': 'Estimate!!Total living in area 1 year ago',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24050_009E': {'attributes': 'B24050_009M,B24050_009EA',
#    'concept': 'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'B24050',
#    'label': 'Estimate!!Total!!Transportation and warehousing, and utilities',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B23002F_009E': {'attributes': 'B23002F_009M,B23002F_009EA',
#    'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER (SOME OTHER RACE ALONE)',
#    'group': 'B23002F',
#    'label': 'Estimate!!Total!!Male!!16 to 19 years!!Not in labor force',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24122_070E': {'attributes': 'B24122_070M,B24122_070EA',
#    'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED MALE POPULATION 16 YEARS AND OVER',
#    'group': 'B24122',
#    'label': 'Estimate!!Total!!Computer occupations, all other',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B04004_017E': {'attributes': 'B04004_017M,B04004_017EA',
#    'concept': 'PEOPLE REPORTING SINGLE ANCESTRY',
#    'group': 'B04004',
#    'label': 'Estimate!!Total!!Assyrian/Chaldean/Syriac',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B15001_047E': {'attributes': 'B15001_047M,B15001_047EA',
#    'concept': 'SEX BY AGE BY EDUCATIONAL ATTAINMENT FOR THE POPULATION 18 YEARS AND OVER',
#    'group': 'B15001',
#    'label': 'Estimate!!Total!!Female!!18 to 24 years!!High school graduate (includes equivalency)',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B08105C_004E': {'attributes': 'B08105C_004M,B08105C_004EA',
#    'concept': 'MEANS OF TRANSPORTATION TO WORK (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#    'group': 'B08105C',
#    'label': 'Estimate!!Total!!Public transportation (excluding taxicab)',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B20005D_084E': {'attributes': 'B20005D_084M,B20005D_084EA',
#    'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (ASIAN ALONE)',
#    'group': 'B20005D',
#    'label': 'Estimate!!Total!!Female!!Other!!With earnings!!$20,000 to $22,499',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24126_255E': {'attributes': 'B24126_255M,B24126_255EA',
#    'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#    'group': 'B24126',
#    'label': 'Estimate!!Total!!Tour and travel guides',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B27005_057E': {'attributes': 'B27005_057M,B27005_057EA',
#    'concept': 'DIRECT-PURCHASE HEALTH INSURANCE BY SEX BY AGE',
#    'group': 'B27005',
#    'label': 'Estimate!!Total!!Female!!75 years and over!!No direct-purchase health insurance',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24126_243E': {'attributes': 'B24126_243M,B24126_243EA',
#    'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#    'group': 'B24126',
#    'label': 'Estimate!!Total!!Animal trainers',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B27007_051E': {'attributes': 'B27007_051M,B27007_051EA',
#    'concept': 'MEDICAID/MEANS-TESTED PUBLIC COVERAGE BY SEX BY AGE',
#    'group': 'B27007',
#    'label': 'Estimate!!Total!!Female!!55 to 64 years!!No Medicaid/means-tested public coverage',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B08505B_005E': {'attributes': 'B08505B_005M,B08505B_005EA',
#    'concept': 'MEANS OF TRANSPORTATION TO WORK FOR WORKPLACE GEOGRAPHY (BLACK OR AFRICAN AMERICAN ALONE)',
#    'group': 'B08505B',
#    'label': 'Estimate!!Total!!Walked',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B17020G_001E': {'attributes': 'B17020G_001M,B17020G_001EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY AGE (TWO OR MORE RACES)',
#    'group': 'B17020G',
#    'label': 'Estimate!!Total',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24122_230E': {'attributes': 'B24122_230M,B24122_230EA',
#    'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED MALE POPULATION 16 YEARS AND OVER',
#    'group': 'B24122',
#    'label': 'Estimate!!Total!!Food servers, nonrestaurant',
#    'limit': 0,
#    'predicateType': 'int'},
# ...
#    'group': 'B24125',
#    'label': 'Estimate!!Total!!Electrical and electronics engineers',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B25013_009E': {'attributes': 'B25013_009M,B25013_009EA',
#    'concept': 'TENURE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#    'group': 'B25013',
#    'label': 'Estimate!!Total!!Renter-occupied housing units!!High school graduate (including equivalency)',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B21001G_006E': {'attributes': 'B21001G_006M,B21001G_006EA',
#    'concept': 'SEX BY AGE BY VETERAN STATUS FOR THE CIVILIAN POPULATION 18 YEARS AND OVER (TWO OR MORE RACES)',
#    'group': 'B21001G',
#    'label': 'Estimate!!Total!!Male!!35 to 54 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B21001B_018E': {'attributes': 'B21001B_018M,B21001B_018EA',
#    'concept': 'SEX BY AGE BY VETERAN STATUS FOR THE CIVILIAN POPULATION 18 YEARS AND OVER (BLACK OR AFRICAN AMERICAN ALONE)',
#    'group': 'B21001B',
#    'label': 'Estimate!!Total!!Female',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24123_515E': {'attributes': 'B24123_515M,B24123_515EA',
#    'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#    'group': 'B24123',
#    'label': 'Estimate!!Total!!Dredge, excavating, and loading machine operators',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B20005F_020E': {'attributes': 'B20005F_020M,B20005F_020EA',
#    'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (SOME OTHER RACE ALONE)',
#    'group': 'B20005F',
#    'label': 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With earnings!!$45,000 to $49,999',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C05006_007E': {'attributes': 'C05006_007M,C05006_007EA',
#    'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION',
#    'group': 'C05006',
#    'label': 'Estimate!!Total!!Europe!!Northern Europe!!Ireland',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B25072_029E': {'attributes': 'B25072_029M,B25072_029EA',
#    'concept': 'AGE OF HOUSEHOLDER BY GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS',
#    'group': 'B25072',
#    'label': 'Estimate!!Total!!Householder 65 years and over!!Not computed',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C17001C_015E': {'attributes': 'C17001C_015M,C17001C_015EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#    'group': 'C17001C',
#    'label': 'Estimate!!Total!!Income in the past 12 months at or above poverty level!!Male!!65 years and over',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B17025_003E': {'attributes': 'B17025_003M,B17025_003EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY NATIVITY',
#    'group': 'B17025',
#    'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Native',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C24080_016E': {'attributes': 'C24080_016M,C24080_016EA',
#    'concept': 'SEX BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'C24080',
#    'label': 'Estimate!!Total!!Female!!Local government workers',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C05006_017E': {'attributes': 'C05006_017M,C05006_017EA',
#    'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION',
#    'group': 'C05006',
#    'label': 'Estimate!!Total!!Europe!!Eastern Europe',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B19126_004E': {'attributes': 'B19126_004M,B19126_004EA',
#    'concept': 'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#    'group': 'B19126',
#    'label': 'Estimate!!Median family income in the past 12 months (in 2016 inflation-adjusted dollars)!!Married-couple family!!No own children of the householder under 18 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C07008_017E': {'attributes': 'C07008_017M,C07008_017EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#    'group': 'C07008',
#    'label': 'Estimate!!Total!!Moved from different county within same state!!Never married',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B27006_043E': {'attributes': 'B27006_043M,B27006_043EA',
#    'concept': 'MEDICARE COVERAGE BY SEX BY AGE',
#    'group': 'B27006',
#    'label': 'Estimate!!Total!!Female!!35 to 44 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B27001E_013E': {'attributes': 'B27001E_013M,B27001E_013EA',
#    'concept': 'HEALTH INSURANCE COVERAGE STATUS BY AGE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#    'group': 'B27001E',
#    'label': 'Estimate!!Total!!25 to 34 years!!No health insurance coverage',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24070_136E': {'attributes': 'B24070_136M,B24070_136EA',
#    'concept': 'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'B24070',
#    'label': 'Estimate!!Total!!Self-employed in own not incorporated business workers and unpaid family workers',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24123_212E': {'attributes': 'B24123_212M,B24123_212EA',
#    'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#    'group': 'B24123',
#    'label': 'Estimate!!Total!!Fish and game wardens',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B04004_008E': {'attributes': 'B04004_008M,B04004_008EA',
#    'concept': 'PEOPLE REPORTING SINGLE ANCESTRY',
#    'group': 'B04004',
#    'label': 'Estimate!!Total!!Arab!!Iraqi',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C08524_008E': {'attributes': 'C08524_008M,C08524_008EA',
#    'concept': 'MEANS OF TRANSPORTATION TO WORK BY OCCUPATION FOR WORKPLACE GEOGRAPHY',
#    'group': 'C08524',
#    'label': 'Estimate!!Total!!Car, truck, or van - drove alone',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B11006_004E': {'attributes': 'B11006_004M,B11006_004EA',
#    'concept': 'HOUSEHOLDS BY PRESENCE OF PEOPLE 60 YEARS AND OVER BY HOUSEHOLD TYPE',
#    'group': 'B11006',
#    'label': 'Estimate!!Total!!Households with one or more people 60 years and over!!Family households!!Married-couple family',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B05001_005E': {'attributes': 'B05001_005M,B05001_005EA',
#    'concept': 'NATIVITY AND CITIZENSHIP STATUS IN THE UNITED STATES',
#    'group': 'B05001',
#    'label': 'Estimate!!Total!!U.S. citizen by naturalization',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B09001_001E': {'attributes': 'B09001_001M,B09001_001EA',
#    'concept': 'POPULATION UNDER 18 YEARS BY AGE',
#    'group': 'B09001',
#    'label': 'Estimate!!Total',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B07409PR_026E': {'attributes': 'B07409PR_026M,B07409PR_026EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR RESIDENCE 1 YEAR AGO IN PUERTO RICO',
#    'group': 'B07409PR',
#    'label': 'Estimate!!Total living in area 1 year ago!!Moved to the United States!!Less than high school graduate',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C15010C_003E': {'attributes': 'C15010C_003M,C15010C_003EA',
#    'concept': "FIELD OF BACHELOR'S DEGREE FOR FIRST MAJOR THE POPULATION 25 YEARS AND OVER (AMERICAN INDIAN AND ALASKA NATIVE ALONE)",
#    'group': 'C15010C',
#    'label': 'Estimate!!Total!!Science and Engineering Related Fields',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C14003_001E': {'attributes': 'C14003_001M,C14003_001EA',
#    'concept': 'SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 3 YEARS AND OVER',
#    'group': 'C14003',
#    'label': 'Estimate!!Total',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C24040_032E': {'attributes': 'C24040_032M,C24040_032EA',
#    'concept': 'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'C24040',
#    'label': 'Estimate!!Total!!Female!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C17001D_010E': {'attributes': 'C17001D_010M,C17001D_010EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (ASIAN ALONE)',
#    'group': 'C17001D',
#    'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!65 years and over',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C27009_003E': {'attributes': 'C27009_003M,C27009_003EA',
#    'concept': 'VA HEALTH CARE BY SEX BY AGE',
#    'group': 'C27009',
#    'label': 'Estimate!!Total!!Male!!Under 18 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B07410_016E': {'attributes': 'B07410_016M,B07410_016EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES',
#    'group': 'B07410',
#    'label': 'Estimate!!Total living in area 1 year ago!!Same house!!With income!!$10,000 to $14,999',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B08011_044E': {'attributes': 'B08011_044M,B08011_044EA',
#    'concept': 'SEX OF WORKERS BY TIME LEAVING HOME TO GO TO WORK',
#    'group': 'B08011',
#    'label': 'Estimate!!Total!!Female!!12:00 p.m. to 3:59 p.m.',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C27016_031E': {'attributes': 'C27016_031M,C27016_031EA',
#    'concept': 'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#    'group': 'C27016',
#    'label': 'Estimate!!Total!!2.00 to 3.99 of poverty threshold!!65 years and over!!No health insurance coverage',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B07401PR_006E': {'attributes': 'B07401PR_006M,B07401PR_006EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR RESIDENCE 1 YEAR AGO IN PUERTO RICO',
#    'group': 'B07401PR',
#    'label': 'Estimate!!Total living in area 1 year ago!!25 to 29 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B17006_004E': {'attributes': 'B17006_004M,B17006_004EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF RELATED CHILDREN UNDER 18 YEARS BY FAMILY TYPE BY AGE OF RELATED CHILDREN UNDER 18 YEARS',
#    'group': 'B17006',
#    'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!In married-couple family!!Under 5 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'C08528_025E': {'attributes': 'C08528_025M,C08528_025EA',
#    'concept': 'MEANS OF TRANSPORTATION TO WORK BY CLASS OF WORKER FOR WORKPLACE GEOGRAPHY',
#    'group': 'C08528',
#    'label': 'Estimate!!Total!!Taxicab, motorcycle, bicycle, walked, or other means!!Unpaid family workers',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B07409_011E': {'attributes': 'B07409_011M,B07409_011EA',
#    'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES',
#    'group': 'B07409',
#    'label': "Estimate!!Total living in area 1 year ago!!Same house!!Bachelor's degree",
#    'limit': 0,
#    'predicateType': 'int'},
#   'C08141_025E': {'attributes': 'C08141_025M,C08141_025EA',
#    'concept': 'MEANS OF TRANSPORTATION TO WORK BY VEHICLES AVAILABLE',
#    'group': 'C08141',
#    'label': 'Estimate!!Total!!Taxicab, motorcycle, bicycle, walked, or other means!!3 or more vehicles available',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B28005_014E': {'attributes': 'B28005_014M,B28005_014EA',
#    'concept': 'AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#    'group': 'B28005',
#    'label': 'Estimate!!Total!!65 years and over',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B25032H_001E': {'attributes': 'B25032H_001M,B25032H_001EA',
#    'concept': 'UNITS IN STRUCTURE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#    'group': 'B25032H',
#    'label': 'Estimate!!Total',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B11003_013E': {'attributes': 'B11003_013M,B11003_013EA',
#    'concept': 'FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN UNDER 18 YEARS',
#    'group': 'B11003',
#    'label': 'Estimate!!Total!!Other family!!Male householder, no wife present!!With own children of the householder under 18 years!!6 to 17 years only',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B05006_095E': {'attributes': 'B05006_095M,B05006_095EA',
#    'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION IN THE UNITED STATES',
#    'group': 'B05006',
#    'label': 'Estimate!!Total!!Africa!!Eastern Africa!!Kenya',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B08541_035E': {'attributes': 'B08541_035M,B08541_035EA',
#    'concept': 'MEANS OF TRANSPORTATION TO WORK BY VEHICLES AVAILABLE FOR WORKPLACE GEOGRAPHY',
#    'group': 'B08541',
#    'label': 'Estimate!!Total!!Worked at home!!3 or more vehicles available',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B27008_056E': {'attributes': 'B27008_056M,B27008_056EA',
#    'concept': 'TRICARE/MILITARY HEALTH COVERAGE BY SEX BY AGE',
#    'group': 'B27008',
#    'label': 'Estimate!!Total!!Female!!75 years and over!!With TRICARE/military health coverage',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24121_101E': {'attributes': 'B24121_101M,B24121_101EA',
#    'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'B24121',
#    'label': 'Estimate!!Total!!Life scientists, all other',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B19001A_006E': {'attributes': 'B19001A_006M,B19001A_006EA',
#    'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#    'group': 'B19001A',
#    'label': 'Estimate!!Total!!$25,000 to $29,999',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24126_025E': {'attributes': 'B24126_025M,B24126_025EA',
#    'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#    'group': 'B24126',
#    'label': 'Estimate!!Total!!Medical and health services managers',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B24080_011E': {'attributes': 'B24080_011M,B24080_011EA',
#    'concept': 'SEX BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#    'group': 'B24080',
#    'label': 'Estimate!!Total!!Male!!Unpaid family workers',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B17020C_003E': {'attributes': 'B17020C_003M,B17020C_003EA',
#    'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#    'group': 'B17020C',
#    'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Under 6 years',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B06002PR_003E': {'attributes': 'B06002PR_003M,B06002PR_003EA',
#    'concept': 'MEDIAN AGE BY PLACE OF BIRTH IN PUERTO RICO',
#    'group': 'B06002PR',
#    'label': 'Estimate!!Median age!!Total!!Born in the United States',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B19037C_007E': {'attributes': 'B19037C_007M,B19037C_007EA',
#    'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#    'group': 'B19037C',
#    'label': 'Estimate!!Total!!Householder under 25 years!!$25,000 to $29,999',
#    'limit': 0,
#    'predicateType': 'int'},
#   'B20005I_012E': {'attributes': 'B20005I_012M,B20005I_012EA',
#    'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (HISPANIC OR LATINO)',
#    'group': 'B20005I',
#    'label': 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With earnings!!$15,000 to $17,499',
#    'limit': 0,
#    'predicateType': 'int'},
#   ...}}

# %%
#turning things into arrays to enable broadcasting
#Python3
affkeys = np.array(list(aff1y['variables'].keys()))
#Python2
#affkeys = np.array(aff1y['variables'].keys())

# %%
aff1y['variables']
#affkeys['B02015_023E']
#B28002_001E
# Out:
# {'B07404APR_002E': {'attributes': 'B07404APR_002M,B07404APR_002EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE) FOR RESIDENCE 1 YEAR AGO IN PUERTO RICO',
#   'group': 'B07404APR',
#   'label': 'Estimate!!Total living in area 1 year ago!!Same house',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24122_137E': {'attributes': 'B24122_137M,B24122_137EA',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED MALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24122',
#   'label': 'Estimate!!Total!!Other teachers and instructors',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24121_235E': {'attributes': 'B24121_235M,B24121_235EA',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'B24121',
#   'label': 'Estimate!!Total!!First-line supervisors of housekeeping and janitorial workers',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B19131_098E': {'attributes': 'B19131_098M,B19131_098EA',
#   'concept': 'FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS BY FAMILY INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS)',
#   'group': 'B19131',
#   'label': 'Estimate!!Total!!Other family!!Female householder, no husband present!!No own children of the householder under 18 years!!$35,000 to $39,999',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B08101_045E': {'attributes': 'B08101_045M,B08101_045EA',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY AGE',
#   'group': 'B08101',
#   'label': 'Estimate!!Total!!Taxicab, motorcycle, bicycle, or other means!!45 to 54 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24010D_060E': {'attributes': 'B24010D_060M,B24010D_060EA',
#   'concept': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER (ASIAN ALONE)',
#   'group': 'B24010D',
#   'label': 'Estimate!!Total!!Female!!Service occupations!!Food preparation and serving related occupations',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B06007_029E': {'attributes': 'B06007_029M,B06007_029EA',
#   'concept': 'PLACE OF BIRTH BY LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH IN THE UNITED STATES',
#   'group': 'B06007',
#   'label': 'Estimate!!Total!!Native; born outside the United States!!Speak Spanish!!Speak English less than "very well"',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C23002I_009E': {'attributes': 'C23002I_009M,C23002I_009EA',
#   'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER (HISPANIC OR LATINO)',
#   'group': 'C23002I',
#   'label': 'Estimate!!Total!!Male!!16 to 64 years!!Not in labor force',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B25075_013E': {'attributes': 'B25075_013M,B25075_013EA',
#   'concept': 'VALUE',
#   'group': 'B25075',
#   'label': 'Estimate!!Total!!$80,000 to $89,999',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B992521_002E': {'attributes': 'B992521_002EA',
#   'concept': 'ALLOCATION OF MORTGAGE STATUS',
#   'group': 'B992521',
#   'label': 'Estimate!!Total!!Allocated',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B23002B_039E': {'attributes': 'B23002B_039M,B23002B_039EA',
#   'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER (BLACK OR AFRICAN AMERICAN ALONE)',
#   'group': 'B23002B',
#   'label': 'Estimate!!Total!!Male!!70 years and over!!In labor force!!Unemployed',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24126_235E': {'attributes': 'B24126_235M,B24126_235EA',
#   'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24126',
#   'label': 'Estimate!!Total!!First-line supervisors of housekeeping and janitorial workers',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B17010H_018E': {'attributes': 'B17010H_018M,B17010H_018EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY PRESENCE OF RELATED CHILDREN UNDER 18 YEARS BY AGE OF RELATED CHILDREN (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'group': 'B17010H',
#   'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Other family!!Female householder, no husband present!!With related children of the householder under 18 years!!Under 5 years only',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07403_014E': {'attributes': 'B07403_014M,B07403_014EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES',
#   'group': 'B07403',
#   'label': 'Estimate!!Total living in area 1 year ago!!Moved to different state!!Male',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C06001PR_024E': {'attributes': 'C06001PR_024M,C06001PR_024EA',
#   'concept': 'PLACE OF BIRTH BY AGE IN PUERTO RICO',
#   'group': 'C06001PR',
#   'label': 'Estimate!!Total!!Born in the United States!!45 to 54 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C17003_007E': {'attributes': 'C17003_007M,C17003_007EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF INDIVIDUALS BY EDUCATIONAL ATTAINMENT',
#   'group': 'C17003',
#   'label': 'Estimate!!Total!!Income in the past 12 months at or above poverty level',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B27006_041E': {'attributes': 'B27006_041M,B27006_041EA',
#   'concept': 'MEDICARE COVERAGE BY SEX BY AGE',
#   'group': 'B27006',
#   'label': 'Estimate!!Total!!Female!!25 to 34 years!!With Medicare coverage',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24121_198E': {'attributes': 'B24121_198M,B24121_198EA',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'B24121',
#   'label': 'Estimate!!Total!!Medical assistants',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C08111_010E': {'attributes': 'C08111_010M,C08111_010EA',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY CITIZENSHIP STATUS',
#   'group': 'C08111',
#   'label': 'Estimate!!Total!!Car, truck, or van - drove alone!!Foreign-born!!Not a U.S. citizen',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07009PR_022E': {'attributes': 'B07009PR_022M,B07009PR_022EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'group': 'B07009PR',
#   'label': "Estimate!!Total!!Moved from different municipio!!Some college or associate's degree",
#   'limit': 0,
#   'predicateType': 'int'},
#  'B16009_021E': {'attributes': 'B16009_021M,B16009_021EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY AGE BY LANGUAGE SPOKEN AT HOME FOR THE POPULATION 5 YEARS AND OVER',
#   'group': 'B16009',
#   'label': 'Estimate!!Total!!Income in the past 12 months at or above poverty level!!5 to 17 years!!Speak other languages',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07204_012E': {'attributes': 'B07204_012M,B07204_012EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--STATE, COUNTY AND PLACE LEVEL IN THE UNITED STATES',
#   'group': 'B07204',
#   'label': 'Estimate!!Total!!Different house in United States 1 year ago!!Elsewhere!!Different county!!Different state!!Northeast',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C08532_001E': {'attributes': 'C08532_001M,C08532_001EA',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY TIME ARRIVING AT WORK FROM HOME FOR WORKPLACE GEOGRAPHY',
#   'group': 'C08532',
#   'label': 'Estimate!!Total',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C15002H_005E': {'attributes': 'C15002H_005M,C15002H_005EA',
#   'concept': 'SEX BY EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'group': 'C15002H',
#   'label': "Estimate!!Total!!Male!!Some college or associate's degree",
#   'limit': 0,
#   'predicateType': 'int'},
#  'B17012_031E': {'attributes': 'B17012_031M,B17012_031EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY NUMBER OF RELATED CHILDREN UNDER 18 YEARS',
#   'group': 'B17012',
#   'label': 'Estimate!!Total!!Income in the past 12 months at or above poverty level!!Other families!!Female householder, no husband present',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24123_016E': {'attributes': 'B24123_016M,B24123_016EA',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24123',
#   'label': 'Estimate!!Total!!Transportation, storage, and distribution managers',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B08122_006E': {'attributes': 'B08122_006M,B08122_006EA',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY POVERTY STATUS IN THE PAST 12 MONTHS',
#   'group': 'B08122',
#   'label': 'Estimate!!Total!!Car, truck, or van - drove alone!!Below 100 percent of the poverty level',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B17010I_041E': {'attributes': 'B17010I_041M,B17010I_041EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY PRESENCE OF RELATED CHILDREN UNDER 18 YEARS BY AGE OF RELATED CHILDREN (HISPANIC OR LATINO)',
#   'group': 'B17010I',
#   'label': 'Estimate!!Total!!Income in the past 12 months at or above poverty level!!Other family!!Female householder, no husband present!!No related children of the householder under 18 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B08412_030E': {'attributes': 'B08412_030M,B08412_030EA',
#   'concept': 'SEX OF WORKERS BY TRAVEL TIME TO WORK FOR WORKPLACE GEOGRAPHY',
#   'group': 'B08412',
#   'label': 'Estimate!!Total!!Female!!10 to 14 minutes',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B27017_068E': {'attributes': 'B27017_068M,B27017_068EA',
#   'concept': 'PRIVATE HEALTH INSURANCE  BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'group': 'B27017',
#   'label': 'Estimate!!Total!!2.50 to 2.99 of poverty threshold!!18 to 64 years!!No private health insurance',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B08119_053E': {'attributes': 'B08119_053M,B08119_053EA',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS)",
#   'group': 'B08119',
#   'label': 'Estimate!!Total!!Taxicab, motorcycle, bicycle, or other means!!$65,000 to $74,999',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B23001_124E': {'attributes': 'B23001_124M,B23001_124EA',
#   'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER',
#   'group': 'B23001',
#   'label': 'Estimate!!Total!!Female!!35 to 44 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B19037H_068E': {'attributes': 'B19037H_068M,B19037H_068EA',
#   'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'group': 'B19037H',
#   'label': 'Estimate!!Total!!Householder 65 years and over!!$150,000 to $199,999',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07009_029E': {'attributes': 'B07009_029M,B07009_029EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'group': 'B07009',
#   'label': "Estimate!!Total!!Moved from different state!!Bachelor's degree",
#   'limit': 0,
#   'predicateType': 'int'},
#  'B08534_019E': {'attributes': 'B08534_019M,B08534_019EA',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY TRAVEL TIME TO WORK FOR WORKPLACE GEOGRAPHY',
#   'group': 'B08534',
#   'label': 'Estimate!!Total!!Car, truck, or van!!45 to 59 minutes',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24010_113E': {'attributes': 'B24010_113M,B24010_113EA',
#   'concept': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'B24010',
#   'label': 'Estimate!!Total!!Male!!Natural resources, construction, and maintenance occupations!!Farming, fishing, and forestry occupations',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B14004_022E': {'attributes': 'B14004_022M,B14004_022EA',
#   'concept': 'SEX BY COLLEGE OR GRADUATE SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 15 YEARS AND OVER',
#   'group': 'B14004',
#   'label': 'Estimate!!Total!!Female!!Enrolled in public college or graduate school!!25 to 34 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24010F_024E': {'attributes': 'B24010F_024M,B24010F_024EA',
#   'concept': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER (SOME OTHER RACE ALONE)',
#   'group': 'B24010F',
#   'label': 'Estimate!!Total!!Male!!Service occupations!!Food preparation and serving related occupations',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B01001G_015E': {'attributes': 'B01001G_015M,B01001G_015EA',
#   'concept': 'SEX BY AGE (TWO OR MORE RACES)',
#   'group': 'B01001G',
#   'label': 'Estimate!!Total!!Male!!75 to 84 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24010_161E': {'attributes': 'B24010_161M,B24010_161EA',
#   'concept': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'B24010',
#   'label': 'Estimate!!Total!!Female!!Management, business, science, and arts occupations!!Management, business, and financial occupations!!Management occupations!!Operations specialties managers except financial managers and human resources managers',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B17001E_012E': {'attributes': 'B17001E_012M,B17001E_012EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'group': 'B17001E',
#   'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!35 to 44 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B19037F_036E': {'attributes': 'B19037F_036M,B19037F_036EA',
#   'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'group': 'B19037F',
#   'label': 'Estimate!!Total!!Householder 45 to 64 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B27001I_005E': {'attributes': 'B27001I_005M,B27001I_005EA',
#   'concept': 'HEALTH INSURANCE COVERAGE STATUS BY AGE (HISPANIC OR LATINO)',
#   'group': 'B27001I',
#   'label': 'Estimate!!Total!!6 to 17 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24122_164E': {'attributes': 'B24122_164M,B24122_164EA',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED MALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24122',
#   'label': 'Estimate!!Total!!Optometrists',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C21001G_012E': {'attributes': 'C21001G_012M,C21001G_012EA',
#   'concept': 'SEX BY AGE BY VETERAN STATUS FOR THE CIVILIAN POPULATION 18 YEARS AND OVER (TWO OR MORE RACES)',
#   'group': 'C21001G',
#   'label': 'Estimate!!Total!!Female!!18 to 64 years!!Nonveteran',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C06001PR_004E': {'attributes': 'C06001PR_004M,C06001PR_004EA',
#   'concept': 'PLACE OF BIRTH BY AGE IN PUERTO RICO',
#   'group': 'C06001PR',
#   'label': 'Estimate!!Total!!18 to 24 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B10063_006E': {'attributes': 'B10063_006M,B10063_006EA',
#   'concept': 'HOUSEHOLDS WITH GRANDPARENTS LIVING WITH OWN GRANDCHILDREN UNDER 18 YEARS BY RESPONSIBILITY FOR OWN GRANDCHILDREN AND PRESENCE OF PARENT OF GRANDCHILDREN',
#   'group': 'B10063',
#   'label': 'Estimate!!Total!!Household with grandparents living with grandchildren!!Household with grandparent not responsible for own grandchildren under 18 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B27006_016E': {'attributes': 'B27006_016M,B27006_016EA',
#   'concept': 'MEDICARE COVERAGE BY SEX BY AGE',
#   'group': 'B27006',
#   'label': 'Estimate!!Total!!Male!!35 to 44 years!!With Medicare coverage',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C15002D_008E': {'attributes': 'C15002D_008M,C15002D_008EA',
#   'concept': 'SEX BY EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER (ASIAN ALONE)',
#   'group': 'C15002D',
#   'label': 'Estimate!!Total!!Female!!Less than high school diploma',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24123_131E': {'attributes': 'B24123_131M,B24123_131EA',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24123',
#   'label': 'Estimate!!Total!!Miscellaneous legal support workers',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07203_005E': {'attributes': 'B07203_005M,B07203_005EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--NOT METROPOLITAN OR MICROPOLITAN STATISTICAL AREA LEVEL IN THE UNITED STATES',
#   'group': 'B07203',
#   'label': 'Estimate!!Total!!Different house in United States 1 year ago!!Metropolitan Statistical Area!!Moved from principal city',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B16010_051E': {'attributes': 'B16010_051M,B16010_051EA',
#   'concept': 'EDUCATIONAL ATTAINMENT AND EMPLOYMENT STATUS BY LANGUAGE SPOKEN AT HOME FOR THE POPULATION 25 YEARS AND OVER',
#   'group': 'B16010',
#   'label': "Estimate!!Total!!Bachelor's degree or higher!!Not in labor force!!Speak other Indo-European languages",
#   'limit': 0,
#   'predicateType': 'int'},
#  'B25038_015E': {'attributes': 'B25038_015M,B25038_015EA',
#   'concept': 'TENURE BY YEAR HOUSEHOLDER MOVED INTO UNIT',
#   'group': 'B25038',
#   'label': 'Estimate!!Total!!Renter occupied!!Moved in 1979 or earlier',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C17001E_012E': {'attributes': 'C17001E_012M,C17001E_012EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'group': 'C17001E',
#   'label': 'Estimate!!Total!!Income in the past 12 months at or above poverty level!!Male',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B12006_011E': {'attributes': 'B12006_011M,B12006_011EA',
#   'concept': 'MARITAL STATUS BY SEX BY LABOR FORCE PARTICIPATION',
#   'group': 'B12006',
#   'label': 'Estimate!!Total!!Never married!!Female!!In labor force!!Unemployed',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B21001E_030E': {'attributes': 'B21001E_030M,B21001E_030EA',
#   'concept': 'SEX BY AGE BY VETERAN STATUS FOR THE CIVILIAN POPULATION 18 YEARS AND OVER (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'group': 'B21001E',
#   'label': 'Estimate!!Total!!Female!!65 to 74 years!!Nonveteran',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24121_201E': {'attributes': 'B24121_201M,B24121_201EA',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'B24121',
#   'label': 'Estimate!!Total!!Veterinary assistants and laboratory animal caretakers',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07001PR_076E': {'attributes': 'B07001PR_076M,B07001PR_076EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'group': 'B07001PR',
#   'label': 'Estimate!!Total!!Moved from the United States!!55 to 59 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B17003_002E': {'attributes': 'B17003_002M,B17003_002EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF INDIVIDUALS BY SEX BY EDUCATIONAL ATTAINMENT',
#   'group': 'B17003',
#   'label': 'Estimate!!Total!!Income in the past 12 months below poverty level',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B02018_015E': {'attributes': 'B02018_015M,B02018_015EA',
#   'concept': 'ASIAN ALONE OR IN ANY COMBINATION BY SELECTED GROUPS',
#   'group': 'B02018',
#   'label': 'Estimate!!Total Groups Tallied!!Mongolian',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B19037B_014E': {'attributes': 'B19037B_014M,B19037B_014EA',
#   'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'group': 'B19037B',
#   'label': 'Estimate!!Total!!Householder under 25 years!!$75,000 to $99,999',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B25129_010E': {'attributes': 'B25129_010M,B25129_010EA',
#   'concept': 'TENURE BY YEAR HOUSEHOLDER MOVED INTO UNIT BY UNITS IN STRUCTURE',
#   'group': 'B25129',
#   'label': 'Estimate!!Total!!Owner occupied!!Moved in 2000 to 2009',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B10053_003E': {'attributes': 'B10053_003M,B10053_003EA',
#   'concept': 'NATIVITY BY GRANDPARENTS RESPONSIBLE FOR OWN GRANDCHILDREN UNDER 18 YEARS BY AGE OF GRANDPARENT',
#   'group': 'B10053',
#   'label': 'Estimate!!Total!!Native!!Grandparent responsible for own grandchildren under 18 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B23001_021E': {'attributes': 'B23001_021M,B23001_021EA',
#   'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER',
#   'group': 'B23001',
#   'label': 'Estimate!!Total!!Male!!22 to 24 years!!In labor force!!Civilian!!Employed',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07009PR_003E': {'attributes': 'B07009PR_003M,B07009PR_003EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'group': 'B07009PR',
#   'label': 'Estimate!!Total!!High school graduate (includes equivalency)',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B19216_013E': {'attributes': 'B19216_013M,B19216_013EA',
#   'concept': 'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'group': 'B19216',
#   'label': 'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2016 inflation-adjusted dollars)!!Female householder (dollars)!!Not living alone (dollars)',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B04004_011E': {'attributes': 'B04004_011M,B04004_011EA',
#   'concept': 'PEOPLE REPORTING SINGLE ANCESTRY',
#   'group': 'B04004',
#   'label': 'Estimate!!Total!!Arab!!Moroccan',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C06001PR_014E': {'attributes': 'C06001PR_014M,C06001PR_014EA',
#   'concept': 'PLACE OF BIRTH BY AGE IN PUERTO RICO',
#   'group': 'C06001PR',
#   'label': 'Estimate!!Total!!Born in Puerto Rico!!25 to 44 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B23002C_067E': {'attributes': 'B23002C_067M,B23002C_067EA',
#   'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'group': 'B23002C',
#   'label': 'Estimate!!Total!!Female!!55 to 64 years!!In labor force!!Civilian!!Employed',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24123_481E': {'attributes': 'B24123_481M,B24123_481EA',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24123',
#   'label': 'Estimate!!Total!!Semiconductor processors',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B17010B_014E': {'attributes': 'B17010B_014M,B17010B_014EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY PRESENCE OF RELATED CHILDREN UNDER 18 YEARS BY AGE OF RELATED CHILDREN (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'group': 'B17010B',
#   'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Other family!!Male householder, no wife present!!With related children of the householder under 18 years!!5 to 17 years only',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C07001_058E': {'attributes': 'C07001_058M,C07001_058EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'group': 'C07001',
#   'label': 'Estimate!!Total!!Moved from abroad!!55 to 64 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B25036_018E': {'attributes': 'B25036_018M,B25036_018EA',
#   'concept': 'TENURE BY YEAR STRUCTURE BUILT',
#   'group': 'B25036',
#   'label': 'Estimate!!Total!!Renter occupied!!Built 1980 to 1989',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B19130_014E': {'attributes': 'B19130_014M,B19130_014EA',
#   'concept': 'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'group': 'B19130',
#   'label': 'Estimate!!Aggregate family income in the past 12 months (in 2016 inflation-adjusted dollars)!!Other family (dollars)!!Male householder, no wife present (dollars)!!Householder 25 to 34 years (dollars)',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C24040_007E': {'attributes': 'C24040_007M,C24040_007EA',
#   'concept': 'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'C24040',
#   'label': 'Estimate!!Total!!Male!!Manufacturing',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B04005_096E': {'attributes': 'B04005_096M,B04005_096EA',
#   'concept': 'PEOPLE REPORTING MULTIPLE ANCESTRY',
#   'group': 'B04005',
#   'label': 'Estimate!!Total!!West Indian (except Hispanic groups)!!Barbadian',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24030_168E': {'attributes': 'B24030_168M,B24030_168EA',
#   'concept': 'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'B24030',
#   'label': 'Estimate!!Total!!Female!!Retail trade!!Retail florists',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24124_479E': {'attributes': 'B24124_479M,B24124_479EA',
#   'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'B24124',
#   'label': 'Estimate!!Total!!Painting workers',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C23002H_026E': {'attributes': 'C23002H_026M,C23002H_026EA',
#   'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'group': 'C23002H',
#   'label': 'Estimate!!Total!!Female!!65 years and over!!In labor force!!Unemployed',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B08534_095E': {'attributes': 'B08534_095M,B08534_095EA',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY TRAVEL TIME TO WORK FOR WORKPLACE GEOGRAPHY',
#   'group': 'B08534',
#   'label': 'Estimate!!Total!!Public transportation (excluding taxicab)!!Railroad or ferryboat!!20 to 24 minutes',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07204_006E': {'attributes': 'B07204_006M,B07204_006EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--STATE, COUNTY AND PLACE LEVEL IN THE UNITED STATES',
#   'group': 'B07204',
#   'label': 'Estimate!!Total!!Different house in United States 1 year ago!!Same city or town!!Different county (same state)',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B18131_070E': {'attributes': 'B18131_070M,B18131_070EA',
#   'concept': 'AGE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY DISABILITY STATUS AND TYPE',
#   'group': 'B18131',
#   'label': 'Estimate!!Total!!18 years and over!!Under .50',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B28010_007E': {'attributes': 'B28010_007M,B28010_007EA',
#   'concept': 'COMPUTERS IN HOUSEHOLD',
#   'group': 'B28010',
#   'label': 'Estimate!!Total!!No Computer',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07203PR_004E': {'attributes': 'B07203PR_004M,B07203PR_004EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--NOT METROPOLITAN OR MICROPOLITAN STATISTICAL AREA LEVEL IN PUERTO RICO',
#   'group': 'B07203PR',
#   'label': 'Estimate!!Total!!Different house in Puerto Rico 1 year ago!!Metropolitan Statistical Area',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B27013_011E': {'attributes': 'B27013_011M,B27013_011EA',
#   'concept': 'PRIVATE HEALTH INSURANCE BY WORK EXPERIENCE BY SEX BY AGE',
#   'group': 'B27013',
#   'label': 'Estimate!!Total!!Worked full-time, year-round!!Female!!18 to 64 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B23002F_048E': {'attributes': 'B23002F_048M,B23002F_048EA',
#   'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER (SOME OTHER RACE ALONE)',
#   'group': 'B23002F',
#   'label': 'Estimate!!Total!!Female!!16 to 19 years!!Not in labor force',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B20005H_068E': {'attributes': 'B20005H_068M,B20005H_068EA',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'group': 'B20005H',
#   'label': 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With earnings!!$50,000 to $54,999',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B21001B_029E': {'attributes': 'B21001B_029M,B21001B_029EA',
#   'concept': 'SEX BY AGE BY VETERAN STATUS FOR THE CIVILIAN POPULATION 18 YEARS AND OVER (BLACK OR AFRICAN AMERICAN ALONE)',
#   'group': 'B21001B',
#   'label': 'Estimate!!Total!!Female!!65 to 74 years!!Veteran',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B12006_049E': {'attributes': 'B12006_049M,B12006_049EA',
#   'concept': 'MARITAL STATUS BY SEX BY LABOR FORCE PARTICIPATION',
#   'group': 'B12006',
#   'label': 'Estimate!!Total!!Divorced!!Male!!In labor force!!Employed or in Armed Forces',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24010_090E': {'attributes': 'B24010_090M,B24010_090EA',
#   'concept': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'B24010',
#   'label': 'Estimate!!Total!!Male!!Service occupations!!Personal care and service occupations!!Baggage porters and concierges, and tour and travel guides',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07201PR_019E': {'attributes': 'B07201PR_019M,B07201PR_019EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--METROPOLITAN STATISTICAL AREA LEVEL IN PUERTO RICO',
#   'group': 'B07201PR',
#   'label': 'Estimate!!Total!!United States 1 year ago!!Micropolitan Statistical Area!!Moved from principal city',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C05006_028E': {'attributes': 'C05006_028M,C05006_028EA',
#   'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION',
#   'group': 'C05006',
#   'label': 'Estimate!!Total!!Asia!!Eastern Asia!!Korea',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B19216_003E': {'attributes': 'B19216_003M,B19216_003EA',
#   'concept': 'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'group': 'B19216',
#   'label': 'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2016 inflation-adjusted dollars)!!Male householder (dollars)!!Living alone (dollars)',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C24010_028E': {'attributes': 'C24010_028M,C24010_028EA',
#   'concept': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'C24010',
#   'label': 'Estimate!!Total!!Male!!Sales and office occupations!!Sales and related occupations',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C23002I_023E': {'attributes': 'C23002I_023M,C23002I_023EA',
#   'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER (HISPANIC OR LATINO)',
#   'group': 'C23002I',
#   'label': 'Estimate!!Total!!Female!!65 years and over',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24060_156E': {'attributes': 'B24060_156M,B24060_156EA',
#   'concept': 'OCCUPATION BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'B24060',
#   'label': 'Estimate!!Total!!Local, state, and federal government workers!!Management, business, science, and arts occupations!!Education, legal, community service, arts, and media occupations!!Legal occupations',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C17009_005E': {'attributes': 'C17009_005M,C17009_005EA',
#   'concept': 'POVERTY STATUS BY WORK EXPERIENCE OF UNRELATED INDIVIDUALS',
#   'group': 'C17009',
#   'label': 'Estimate!!Total!!Income in the past 12 months below the poverty level!!Did not work',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B27011_004E': {'attributes': 'B27011_004M,B27011_004EA',
#   'concept': 'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY EMPLOYMENT STATUS BY AGE',
#   'group': 'B27011',
#   'label': 'Estimate!!Total!!In labor force!!Employed!!18 to 64 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B09020_019E': {'attributes': 'B09020_019M,B09020_019EA',
#   'concept': 'RELATIONSHIP BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) FOR THE POPULATION 65 YEARS AND OVER',
#   'group': 'B09020',
#   'label': 'Estimate!!Total!!In households!!In nonfamily households!!Householder!!Female!!Not living alone',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24125_035E': {'attributes': 'B24125_035M,B24125_035EA',
#   'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED MALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24125',
#   'label': 'Estimate!!Total!!Purchasing agents, except wholesale, retail, and farm products',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B23006_008E': {'attributes': 'B23006_008M,B23006_008EA',
#   'concept': 'EDUCATIONAL ATTAINMENT BY EMPLOYMENT STATUS FOR THE POPULATION 25 TO 64 YEARS',
#   'group': 'B23006',
#   'label': 'Estimate!!Total!!Less than high school graduate!!Not in labor force',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C06010PR_030E': {'attributes': 'C06010PR_030M,C06010PR_030EA',
#   'concept': 'PLACE OF BIRTH BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) IN PUERTO RICO',
#   'group': 'C06010PR',
#   'label': 'Estimate!!Total!!Born in the United States!!With income!!$35,000 to $49,999',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B23027_024E': {'attributes': 'B23027_024M,B23027_024EA',
#   'concept': 'FULL-TIME, YEAR-ROUND WORK STATUS IN THE PAST 12 MONTHS BY AGE FOR THE POPULATION 16 YEARS AND OVER',
#   'group': 'B23027',
#   'label': 'Estimate!!Total!!55 to 64 years!!Worked in the past 12 months!!Worked full-time, year-round',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24125_071E': {'attributes': 'B24125_071M,B24125_071EA',
#   'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED MALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24125',
#   'label': 'Estimate!!Total!!Actuaries',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B18135_028E': {'attributes': 'B18135_028M,B18135_028EA',
#   'concept': 'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'group': 'B18135',
#   'label': 'Estimate!!Total!!65 years and over!!With a disability!!With health insurance coverage!!With public health coverage',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B08536_011E': {'attributes': 'B08536_011M,B08536_011EA',
#   'concept': 'AGGREGATE TRAVEL TIME TO WORK (IN MINUTES) OF WORKERS BY MEANS OF TRANSPORTATION TO WORK FOR WORKPLACE GEOGRAPHY',
#   'group': 'B08536',
#   'label': 'Estimate!!Aggregate travel time to work (in minutes)!!Walked',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C08534_003E': {'attributes': 'C08534_003M,C08534_003EA',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY TRAVEL TIME TO WORK FOR WORKPLACE GEOGRAPHY',
#   'group': 'C08534',
#   'label': 'Estimate!!Total!!10 to 14 minutes',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B20005_090E': {'attributes': 'B20005_090M,B20005_090EA',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'group': 'B20005',
#   'label': 'Estimate!!Total!!Female!!Other!!With earnings!!$45,000 to $49,999',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B25121_079E': {'attributes': 'B25121_079M,B25121_079EA',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) BY VALUE',
#   'group': 'B25121',
#   'label': 'Estimate!!Total!!Household income the past 12 months (in 2016 inflation-adjusted dollars)!!$75,000 to $99,999!!Value $10,000 to $19,999',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B17001G_004E': {'attributes': 'B17001G_004M,B17001G_004EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (TWO OR MORE RACES)',
#   'group': 'B17001G',
#   'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!Under 5 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24123_115E': {'attributes': 'B24123_115M,B24123_115EA',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24123',
#   'label': 'Estimate!!Total!!Geological and petroleum technicians',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B08134_063E': {'attributes': 'B08134_063M,B08134_063EA',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY TRAVEL TIME TO WORK',
#   'group': 'B08134',
#   'label': 'Estimate!!Total!!Public transportation (excluding taxicab)!!10 to 14 minutes',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C23004_002E': {'attributes': 'C23004_002M,C23004_002EA',
#   'concept': 'WORK STATUS IN THE PAST 12 MONTHS BY EMPLOYMENT STATUS FOR THE CIVILIAN POPULATION 65 YEARS AND OVER',
#   'group': 'C23004',
#   'label': 'Estimate!!Total!!Worked in the past 12 months',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07409PR_007E': {'attributes': 'B07409PR_007M,B07409PR_007EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR RESIDENCE 1 YEAR AGO IN PUERTO RICO',
#   'group': 'B07409PR',
#   'label': 'Estimate!!Total living in area 1 year ago!!Same house',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24050_047E': {'attributes': 'B24050_047M,B24050_047EA',
#   'concept': 'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'B24050',
#   'label': 'Estimate!!Total!!Management, business, science, and arts occupations!!Educational services, and health care and social assistance',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B27015_009E': {'attributes': 'B27015_009M,B27015_009EA',
#   'concept': 'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS)',
#   'group': 'B27015',
#   'label': 'Estimate!!Total!!$25,000 to $49,999!!With health insurance coverage!!With private health insurance',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B08130_007E': {'attributes': 'B08130_007M,B08130_007EA',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY PLACE OF WORK--STATE AND COUNTY LEVEL',
#   'group': 'B08130',
#   'label': 'Estimate!!Total!!Car, truck, or van - drove alone!!Worked in state of residence',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07101_020E': {'attributes': 'B07101_020M,B07101_020EA',
#   'concept': 'MOVERS BETWEEN REGIONS IN THE UNITED STATES',
#   'group': 'B07101',
#   'label': 'Estimate!!Total!!Current residence; Northeast!!Movers to different state!!Residence 1 year ago!!West',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C17006_001E': {'attributes': 'C17006_001M,C17006_001EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF RELATED CHILDREN UNDER 18 YEARS BY FAMILY TYPE',
#   'group': 'C17006',
#   'label': 'Estimate!!Total',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C17001B_012E': {'attributes': 'C17001B_012M,C17001B_012EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'group': 'C17001B',
#   'label': 'Estimate!!Total!!Income in the past 12 months at or above poverty level!!Male',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B18103_021E': {'attributes': 'B18103_021M,B18103_021EA',
#   'concept': 'SEX BY AGE BY VISION DIFFICULTY',
#   'group': 'B18103',
#   'label': 'Estimate!!Total!!Female',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C24040_020E': {'attributes': 'C24040_020M,C24040_020EA',
#   'concept': 'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'C24040',
#   'label': 'Estimate!!Total!!Male!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B16005C_006E': {'attributes': 'B16005C_006M,B16005C_006EA',
#   'concept': 'NATIVITY BY LANGUAGE SPOKEN AT HOME BY ABILITY TO SPEAK ENGLISH FOR THE POPULATION 5 YEARS AND OVER (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'group': 'B16005C',
#   'label': 'Estimate!!Total!!Native!!Speak another language!!Speak English less than "very well"',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24010H_010E': {'attributes': 'B24010H_010M,B24010H_010EA',
#   'concept': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'group': 'B24010H',
#   'label': 'Estimate!!Total!!Male!!Management, business, science, and arts occupations!!Computer, engineering, and science occupations!!Life, physical, and social science occupations',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B25106_002E': {'attributes': 'B25106_002M,B25106_002EA',
#   'concept': 'TENURE BY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS',
#   'group': 'B25106',
#   'label': 'Estimate!!Total!!Owner-occupied housing units',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24125_043E': {'attributes': 'B24125_043M,B24125_043EA',
#   'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED MALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24125',
#   'label': 'Estimate!!Total!!Management analysts',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B19216_005E': {'attributes': 'B19216_005M,B19216_005EA',
#   'concept': 'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'group': 'B19216',
#   'label': 'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2016 inflation-adjusted dollars)!!Male householder (dollars)!!Living alone (dollars)!!Householder 65 years and over (dollars)',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B08537_013E': {'attributes': 'B08537_013M,B08537_013EA',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY TENURE FOR WORKPLACE GEOGRAPHY',
#   'group': 'B08537',
#   'label': 'Estimate!!Total!!Walked',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B27004_025E': {'attributes': 'B27004_025M,B27004_025EA',
#   'concept': 'EMPLOYER-BASED HEALTH INSURANCE  BY SEX BY AGE',
#   'group': 'B27004',
#   'label': 'Estimate!!Total!!Male!!65 to 74 years!!With employer-based health insurance',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C27006_010E': {'attributes': 'C27006_010M,C27006_010EA',
#   'concept': 'MEDICARE COVERAGE BY SEX BY AGE',
#   'group': 'C27006',
#   'label': 'Estimate!!Total!!Male!!65 years and over!!With Medicare coverage',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07407PR_001E': {'attributes': 'B07407PR_001M,B07407PR_001EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR RESIDENCE 1 YEAR AGO IN PUERTO RICO',
#   'group': 'B07407PR',
#   'label': 'Estimate!!Total living in area 1 year ago',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24050_009E': {'attributes': 'B24050_009M,B24050_009EA',
#   'concept': 'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'B24050',
#   'label': 'Estimate!!Total!!Transportation and warehousing, and utilities',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B23002F_009E': {'attributes': 'B23002F_009M,B23002F_009EA',
#   'concept': 'SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER (SOME OTHER RACE ALONE)',
#   'group': 'B23002F',
#   'label': 'Estimate!!Total!!Male!!16 to 19 years!!Not in labor force',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24122_070E': {'attributes': 'B24122_070M,B24122_070EA',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED MALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24122',
#   'label': 'Estimate!!Total!!Computer occupations, all other',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B04004_017E': {'attributes': 'B04004_017M,B04004_017EA',
#   'concept': 'PEOPLE REPORTING SINGLE ANCESTRY',
#   'group': 'B04004',
#   'label': 'Estimate!!Total!!Assyrian/Chaldean/Syriac',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B15001_047E': {'attributes': 'B15001_047M,B15001_047EA',
#   'concept': 'SEX BY AGE BY EDUCATIONAL ATTAINMENT FOR THE POPULATION 18 YEARS AND OVER',
#   'group': 'B15001',
#   'label': 'Estimate!!Total!!Female!!18 to 24 years!!High school graduate (includes equivalency)',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B08105C_004E': {'attributes': 'B08105C_004M,B08105C_004EA',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'group': 'B08105C',
#   'label': 'Estimate!!Total!!Public transportation (excluding taxicab)',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B20005D_084E': {'attributes': 'B20005D_084M,B20005D_084EA',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (ASIAN ALONE)',
#   'group': 'B20005D',
#   'label': 'Estimate!!Total!!Female!!Other!!With earnings!!$20,000 to $22,499',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24126_255E': {'attributes': 'B24126_255M,B24126_255EA',
#   'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24126',
#   'label': 'Estimate!!Total!!Tour and travel guides',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B27005_057E': {'attributes': 'B27005_057M,B27005_057EA',
#   'concept': 'DIRECT-PURCHASE HEALTH INSURANCE BY SEX BY AGE',
#   'group': 'B27005',
#   'label': 'Estimate!!Total!!Female!!75 years and over!!No direct-purchase health insurance',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24126_243E': {'attributes': 'B24126_243M,B24126_243EA',
#   'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24126',
#   'label': 'Estimate!!Total!!Animal trainers',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B27007_051E': {'attributes': 'B27007_051M,B27007_051EA',
#   'concept': 'MEDICAID/MEANS-TESTED PUBLIC COVERAGE BY SEX BY AGE',
#   'group': 'B27007',
#   'label': 'Estimate!!Total!!Female!!55 to 64 years!!No Medicaid/means-tested public coverage',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B08505B_005E': {'attributes': 'B08505B_005M,B08505B_005EA',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK FOR WORKPLACE GEOGRAPHY (BLACK OR AFRICAN AMERICAN ALONE)',
#   'group': 'B08505B',
#   'label': 'Estimate!!Total!!Walked',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B17020G_001E': {'attributes': 'B17020G_001M,B17020G_001EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY AGE (TWO OR MORE RACES)',
#   'group': 'B17020G',
#   'label': 'Estimate!!Total',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24122_230E': {'attributes': 'B24122_230M,B24122_230EA',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED MALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24122',
#   'label': 'Estimate!!Total!!Food servers, nonrestaurant',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07403_007E': {'attributes': 'B07403_007M,B07403_007EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES',
#   'group': 'B07403',
#   'label': 'Estimate!!Total living in area 1 year ago!!Moved within same county',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C17001H_012E': {'attributes': 'C17001H_012M,C17001H_012EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'group': 'C17001H',
#   'label': 'Estimate!!Total!!Income in the past 12 months at or above poverty level!!Male',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07407_009E': {'attributes': 'B07407_009M,B07407_009EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES',
#   'group': 'B07407',
# ...
#   'group': 'B05008',
#   'label': 'Estimate!!Total!!Female!!Latin America!!Central America!!Other Central America',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24125_084E': {'attributes': 'B24125_084M,B24125_084EA',
#   'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED MALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24125',
#   'label': 'Estimate!!Total!!Electrical and electronics engineers',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B25013_009E': {'attributes': 'B25013_009M,B25013_009EA',
#   'concept': 'TENURE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'group': 'B25013',
#   'label': 'Estimate!!Total!!Renter-occupied housing units!!High school graduate (including equivalency)',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B21001G_006E': {'attributes': 'B21001G_006M,B21001G_006EA',
#   'concept': 'SEX BY AGE BY VETERAN STATUS FOR THE CIVILIAN POPULATION 18 YEARS AND OVER (TWO OR MORE RACES)',
#   'group': 'B21001G',
#   'label': 'Estimate!!Total!!Male!!35 to 54 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B21001B_018E': {'attributes': 'B21001B_018M,B21001B_018EA',
#   'concept': 'SEX BY AGE BY VETERAN STATUS FOR THE CIVILIAN POPULATION 18 YEARS AND OVER (BLACK OR AFRICAN AMERICAN ALONE)',
#   'group': 'B21001B',
#   'label': 'Estimate!!Total!!Female',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24123_515E': {'attributes': 'B24123_515M,B24123_515EA',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24123',
#   'label': 'Estimate!!Total!!Dredge, excavating, and loading machine operators',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B20005F_020E': {'attributes': 'B20005F_020M,B20005F_020EA',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (SOME OTHER RACE ALONE)',
#   'group': 'B20005F',
#   'label': 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With earnings!!$45,000 to $49,999',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C05006_007E': {'attributes': 'C05006_007M,C05006_007EA',
#   'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION',
#   'group': 'C05006',
#   'label': 'Estimate!!Total!!Europe!!Northern Europe!!Ireland',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B25072_029E': {'attributes': 'B25072_029M,B25072_029EA',
#   'concept': 'AGE OF HOUSEHOLDER BY GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS',
#   'group': 'B25072',
#   'label': 'Estimate!!Total!!Householder 65 years and over!!Not computed',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C17001C_015E': {'attributes': 'C17001C_015M,C17001C_015EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'group': 'C17001C',
#   'label': 'Estimate!!Total!!Income in the past 12 months at or above poverty level!!Male!!65 years and over',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B17025_003E': {'attributes': 'B17025_003M,B17025_003EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY NATIVITY',
#   'group': 'B17025',
#   'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Native',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C24080_016E': {'attributes': 'C24080_016M,C24080_016EA',
#   'concept': 'SEX BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'C24080',
#   'label': 'Estimate!!Total!!Female!!Local government workers',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C05006_017E': {'attributes': 'C05006_017M,C05006_017EA',
#   'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION',
#   'group': 'C05006',
#   'label': 'Estimate!!Total!!Europe!!Eastern Europe',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B19126_004E': {'attributes': 'B19126_004M,B19126_004EA',
#   'concept': 'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'group': 'B19126',
#   'label': 'Estimate!!Median family income in the past 12 months (in 2016 inflation-adjusted dollars)!!Married-couple family!!No own children of the householder under 18 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C07008_017E': {'attributes': 'C07008_017M,C07008_017EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'group': 'C07008',
#   'label': 'Estimate!!Total!!Moved from different county within same state!!Never married',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B27006_043E': {'attributes': 'B27006_043M,B27006_043EA',
#   'concept': 'MEDICARE COVERAGE BY SEX BY AGE',
#   'group': 'B27006',
#   'label': 'Estimate!!Total!!Female!!35 to 44 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B27001E_013E': {'attributes': 'B27001E_013M,B27001E_013EA',
#   'concept': 'HEALTH INSURANCE COVERAGE STATUS BY AGE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'group': 'B27001E',
#   'label': 'Estimate!!Total!!25 to 34 years!!No health insurance coverage',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24070_136E': {'attributes': 'B24070_136M,B24070_136EA',
#   'concept': 'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'B24070',
#   'label': 'Estimate!!Total!!Self-employed in own not incorporated business workers and unpaid family workers',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24123_212E': {'attributes': 'B24123_212M,B24123_212EA',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24123',
#   'label': 'Estimate!!Total!!Fish and game wardens',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B04004_008E': {'attributes': 'B04004_008M,B04004_008EA',
#   'concept': 'PEOPLE REPORTING SINGLE ANCESTRY',
#   'group': 'B04004',
#   'label': 'Estimate!!Total!!Arab!!Iraqi',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C08524_008E': {'attributes': 'C08524_008M,C08524_008EA',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY OCCUPATION FOR WORKPLACE GEOGRAPHY',
#   'group': 'C08524',
#   'label': 'Estimate!!Total!!Car, truck, or van - drove alone',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B11006_004E': {'attributes': 'B11006_004M,B11006_004EA',
#   'concept': 'HOUSEHOLDS BY PRESENCE OF PEOPLE 60 YEARS AND OVER BY HOUSEHOLD TYPE',
#   'group': 'B11006',
#   'label': 'Estimate!!Total!!Households with one or more people 60 years and over!!Family households!!Married-couple family',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B05001_005E': {'attributes': 'B05001_005M,B05001_005EA',
#   'concept': 'NATIVITY AND CITIZENSHIP STATUS IN THE UNITED STATES',
#   'group': 'B05001',
#   'label': 'Estimate!!Total!!U.S. citizen by naturalization',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B09001_001E': {'attributes': 'B09001_001M,B09001_001EA',
#   'concept': 'POPULATION UNDER 18 YEARS BY AGE',
#   'group': 'B09001',
#   'label': 'Estimate!!Total',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07409PR_026E': {'attributes': 'B07409PR_026M,B07409PR_026EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR RESIDENCE 1 YEAR AGO IN PUERTO RICO',
#   'group': 'B07409PR',
#   'label': 'Estimate!!Total living in area 1 year ago!!Moved to the United States!!Less than high school graduate',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C15010C_003E': {'attributes': 'C15010C_003M,C15010C_003EA',
#   'concept': "FIELD OF BACHELOR'S DEGREE FOR FIRST MAJOR THE POPULATION 25 YEARS AND OVER (AMERICAN INDIAN AND ALASKA NATIVE ALONE)",
#   'group': 'C15010C',
#   'label': 'Estimate!!Total!!Science and Engineering Related Fields',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C14003_001E': {'attributes': 'C14003_001M,C14003_001EA',
#   'concept': 'SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 3 YEARS AND OVER',
#   'group': 'C14003',
#   'label': 'Estimate!!Total',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C24040_032E': {'attributes': 'C24040_032M,C24040_032EA',
#   'concept': 'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'C24040',
#   'label': 'Estimate!!Total!!Female!!Agriculture, forestry, fishing and hunting, and mining!!Mining, quarrying, and oil and gas extraction',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C17001D_010E': {'attributes': 'C17001D_010M,C17001D_010EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE (ASIAN ALONE)',
#   'group': 'C17001D',
#   'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!65 years and over',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C27009_003E': {'attributes': 'C27009_003M,C27009_003EA',
#   'concept': 'VA HEALTH CARE BY SEX BY AGE',
#   'group': 'C27009',
#   'label': 'Estimate!!Total!!Male!!Under 18 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07410_016E': {'attributes': 'B07410_016M,B07410_016EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES',
#   'group': 'B07410',
#   'label': 'Estimate!!Total living in area 1 year ago!!Same house!!With income!!$10,000 to $14,999',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B08011_044E': {'attributes': 'B08011_044M,B08011_044EA',
#   'concept': 'SEX OF WORKERS BY TIME LEAVING HOME TO GO TO WORK',
#   'group': 'B08011',
#   'label': 'Estimate!!Total!!Female!!12:00 p.m. to 3:59 p.m.',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C27016_031E': {'attributes': 'C27016_031M,C27016_031EA',
#   'concept': 'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'group': 'C27016',
#   'label': 'Estimate!!Total!!2.00 to 3.99 of poverty threshold!!65 years and over!!No health insurance coverage',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07401PR_006E': {'attributes': 'B07401PR_006M,B07401PR_006EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR RESIDENCE 1 YEAR AGO IN PUERTO RICO',
#   'group': 'B07401PR',
#   'label': 'Estimate!!Total living in area 1 year ago!!25 to 29 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B17006_004E': {'attributes': 'B17006_004M,B17006_004EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF RELATED CHILDREN UNDER 18 YEARS BY FAMILY TYPE BY AGE OF RELATED CHILDREN UNDER 18 YEARS',
#   'group': 'B17006',
#   'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!In married-couple family!!Under 5 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'C08528_025E': {'attributes': 'C08528_025M,C08528_025EA',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY CLASS OF WORKER FOR WORKPLACE GEOGRAPHY',
#   'group': 'C08528',
#   'label': 'Estimate!!Total!!Taxicab, motorcycle, bicycle, walked, or other means!!Unpaid family workers',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B07409_011E': {'attributes': 'B07409_011M,B07409_011EA',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES',
#   'group': 'B07409',
#   'label': "Estimate!!Total living in area 1 year ago!!Same house!!Bachelor's degree",
#   'limit': 0,
#   'predicateType': 'int'},
#  'C08141_025E': {'attributes': 'C08141_025M,C08141_025EA',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY VEHICLES AVAILABLE',
#   'group': 'C08141',
#   'label': 'Estimate!!Total!!Taxicab, motorcycle, bicycle, walked, or other means!!3 or more vehicles available',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B28005_014E': {'attributes': 'B28005_014M,B28005_014EA',
#   'concept': 'AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'group': 'B28005',
#   'label': 'Estimate!!Total!!65 years and over',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B25032H_001E': {'attributes': 'B25032H_001M,B25032H_001EA',
#   'concept': 'UNITS IN STRUCTURE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'group': 'B25032H',
#   'label': 'Estimate!!Total',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B11003_013E': {'attributes': 'B11003_013M,B11003_013EA',
#   'concept': 'FAMILY TYPE BY PRESENCE AND AGE OF OWN CHILDREN UNDER 18 YEARS',
#   'group': 'B11003',
#   'label': 'Estimate!!Total!!Other family!!Male householder, no wife present!!With own children of the householder under 18 years!!6 to 17 years only',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B05006_095E': {'attributes': 'B05006_095M,B05006_095EA',
#   'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION IN THE UNITED STATES',
#   'group': 'B05006',
#   'label': 'Estimate!!Total!!Africa!!Eastern Africa!!Kenya',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B08541_035E': {'attributes': 'B08541_035M,B08541_035EA',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY VEHICLES AVAILABLE FOR WORKPLACE GEOGRAPHY',
#   'group': 'B08541',
#   'label': 'Estimate!!Total!!Worked at home!!3 or more vehicles available',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B27008_056E': {'attributes': 'B27008_056M,B27008_056EA',
#   'concept': 'TRICARE/MILITARY HEALTH COVERAGE BY SEX BY AGE',
#   'group': 'B27008',
#   'label': 'Estimate!!Total!!Female!!75 years and over!!With TRICARE/military health coverage',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24121_101E': {'attributes': 'B24121_101M,B24121_101EA',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'B24121',
#   'label': 'Estimate!!Total!!Life scientists, all other',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B19001A_006E': {'attributes': 'B19001A_006M,B19001A_006EA',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'group': 'B19001A',
#   'label': 'Estimate!!Total!!$25,000 to $29,999',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24126_025E': {'attributes': 'B24126_025M,B24126_025EA',
#   'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'group': 'B24126',
#   'label': 'Estimate!!Total!!Medical and health services managers',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B24080_011E': {'attributes': 'B24080_011M,B24080_011EA',
#   'concept': 'SEX BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'group': 'B24080',
#   'label': 'Estimate!!Total!!Male!!Unpaid family workers',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B17020C_003E': {'attributes': 'B17020C_003M,B17020C_003EA',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'group': 'B17020C',
#   'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Under 6 years',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B06002PR_003E': {'attributes': 'B06002PR_003M,B06002PR_003EA',
#   'concept': 'MEDIAN AGE BY PLACE OF BIRTH IN PUERTO RICO',
#   'group': 'B06002PR',
#   'label': 'Estimate!!Median age!!Total!!Born in the United States',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B19037C_007E': {'attributes': 'B19037C_007M,B19037C_007EA',
#   'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'group': 'B19037C',
#   'label': 'Estimate!!Total!!Householder under 25 years!!$25,000 to $29,999',
#   'limit': 0,
#   'predicateType': 'int'},
#  'B20005I_012E': {'attributes': 'B20005I_012M,B20005I_012EA',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (HISPANIC OR LATINO)',
#   'group': 'B20005I',
#   'label': 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With earnings!!$15,000 to $17,499',
#   'limit': 0,
#   'predicateType': 'int'},
#  ...}

# %% [markdown]
# You need two features: **total number of households**, and **number of households with broadband access**
#
# Broadband access is one of the B28002 keys. However there are many of those! Each variable has several observations associated to it: B28002 is all internet access data (broadband, dial up, none, ...), and for each of those you have the estimate (count, mean, median, percentage...), the margin of errors, and annotations. Those are identified by an appendix that begins with "\_". Look carefully at the line of code below and its output. I am creating a list that contains the keys of the dictionary I created from the json file for all B28002 observations  (rows that start with "B28002") that include the word "Broadband" in the description.
#
# The syntax is a lost comprehension:
#
#         as = \[a for a in listOfAs\]
#
# is simply a compact way to write
#
#         as = \[\]
#         for a in listOfAs:
#             as.append(a)
#
# with an if statement tha selects broadband

# %%
#extracting variables of B28002 that contain "broadband"
[(k, aff1y['variables'][k]['label'])  for k in affkeys if k.startswith ("B28002") and 
 'Broadband' in aff1y['variables'][k]['label']]
# Out:
# [('B28002_004E',
#   'Estimate!!Total!!With an Internet subscription!!Broadband of any type'),
#  ('B28002_008E',
#   'Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL!!Broadband such as cable, fiber optic or DSL with no other type of Internet subscription'),
#  ('B28002_007E',
#   'Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL')]

# %% [markdown]
# chose the appropriate variable and extract the relevant data: below I select the variable containing the number of household per PUMA. The "all" variable, which tells you what is the total number of units queried (households here) is generally stored in the \_001 variable (B28002_001 in this case). "E" stands for *estimate*. M stands for *margin of error*, EA *estimate annotations*, MA *margin of error annotations*. You want the estimate for this exercise.

# %%
#keyword for the number of households
keyNhouseholds = 'B28002_001E'
aff1y['variables'][keyNhouseholds]
# Out:
# {'attributes': 'B28002_001M,B28002_001EA',
#  'concept': 'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#  'group': 'B28002',
#  'label': 'Estimate!!Total',
#  'limit': 0,
#  'predicateType': 'int'}

# %% [markdown]
# Similarly, choose the fractions of houses with any "With an Internet subscription!!Broadband of any type"

# %%
#keyword for the number of households with broarband access
keyNBB = 'B28002_004E'
aff1y['variables'][keyNBB]
# Out:
# {'attributes': 'B28002_004M,B28002_004EA',
#  'concept': 'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#  'group': 'B28002',
#  'label': 'Estimate!!Total!!With an Internet subscription!!Broadband of any type',
#  'limit': 0,
#  'predicateType': 'int'}

# %%
myAPI=os.getenv ('MYAPI')

# %% [markdown]
# Now that you have the variable names use them to extract the relevant data with the ACS API.
#
# The API url is as follows:
#
# root: https://api.census.gov/data/2016/acs/acs1
#
# action: get=\[variable Name\],NAME
#
# geometry: for=\[geometry\]:\[desired geometry values\]in=\[larger geometry\]:\[desired larger geometry values\]
#
# API key: key:\[api key\]
#
# the URL is constructed as root?action&geometry&key
#
# Note that it took me a long time to figure out how to request the right geometry: in the url I write below the geometry is "public%20use%20microdata%20area" where %20 is the character for ' ' (space) in a url, and ":\*" means all PUMAS
#
# state:36 is New York State

# %%
# getting the broadband access number of households
url = "https://api.census.gov/data/2016/acs/acs1?get=" + keyNBB +\
 ",NAME&for=public%20use%20microdata%20area:*&in=state:36&key=" + myAPI
resp = requests.request('GET', url).content
pumaBB = pd.read_csv(io.StringIO(resp.decode('utf-8').replace('[','').replace(']','')))

pumaBB.head()
# Out:
#    B28002_004E                                               NAME  state  \
# 0        32607                 St. Lawrence County PUMA, New York     36
# 1        50811  Clinton, Franklin, Essex & Hamilton Counties P...     36
# 2        41210        Warren & Washington Counties PUMA, New York     36
# 3        36075  Herkimer (North & Central) & Oneida (Outer) Co...     36
# 4        47786  Oneida County (Central)--Greater Utica & Rome ...     36
#
#    public use microdata area  Unnamed: 4
# 0                        100         NaN
# 1                        200         NaN
# 2                        300         NaN
# 3                        401         NaN
# 4                        402         NaN

# %%
#getting the first row of the table: the total number of households
url = "https://api.census.gov/data/2016/acs/acs1?get=" + keyNhouseholds +\
",NAME&for=public%20use%20microdata%20area:*&in=state:36&key=" + myAPI
resp = requests.request('GET', url).content
pumaPP = pd.read_csv(io.StringIO(resp.decode('utf-8').replace('[','').replace(']','')))

# %%
pumaPP.head()
# Out:
#    B28002_001E                                               NAME  state  \
# 0        40479                 St. Lawrence County PUMA, New York     36
# 1        67092  Clinton, Franklin, Essex & Hamilton Counties P...     36
# 2        51614        Warren & Washington Counties PUMA, New York     36
# 3        44300  Herkimer (North & Central) & Oneida (Outer) Co...     36
# 4        61146  Oneida County (Central)--Greater Utica & Rome ...     36
#
#    public use microdata area  Unnamed: 4
# 0                        100         NaN
# 1                        200         NaN
# 2                        300         NaN
# 3                        401         NaN
# 4                        402         NaN

# %% [markdown]
# ## 2.2 generate a feature for the percentage of households with broadband access

# %%
merged=pumaBB.merge(pumaPP, on="public use microdata area")
merged['Percentage']=(merged['B28002_004E']/merged['B28002_001E'])*100
final=merged.drop(['NAME_y', 'state_y', 'Unnamed: 4_y'], axis=1)
pumaBBf=final.rename(columns={"NAME_x":"NAME", "state_x":"state"})
pumaBBf.head()
# Out:
#    B28002_004E                                               NAME  state  \
# 0        32607                 St. Lawrence County PUMA, New York     36
# 1        50811  Clinton, Franklin, Essex & Hamilton Counties P...     36
# 2        41210        Warren & Washington Counties PUMA, New York     36
# 3        36075  Herkimer (North & Central) & Oneida (Outer) Co...     36
# 4        47786  Oneida County (Central)--Greater Utica & Rome ...     36
#
#    public use microdata area  Unnamed: 4_x  B28002_001E  Percentage
# 0                        100           NaN        40479   80.552879
# 1                        200           NaN        67092   75.733321
# 2                        300           NaN        51614   79.842678
# 3                        401           NaN        44300   81.433409
# 4                        402           NaN        61146   78.150656

# %%
pumaBB.head()
# Out:
#    B28002_004E                                               NAME  state  \
# 0        32607                 St. Lawrence County PUMA, New York     36
# 1        50811  Clinton, Franklin, Essex & Hamilton Counties P...     36
# 2        41210        Warren & Washington Counties PUMA, New York     36
# 3        36075  Herkimer (North & Central) & Oneida (Outer) Co...     36
# 4        47786  Oneida County (Central)--Greater Utica & Rome ...     36
#
#    public use microdata area  Unnamed: 4
# 0                        100         NaN
# 1                        200         NaN
# 2                        300         NaN
# 3                        401         NaN
# 4                        402         NaN

# %% [markdown]
# ## 2.3 Now compare it with the AFF published "percentage of households with broadband access" which is a feature available through their website but that cannot be downloaded directly from the API. It compiled by AFF the same way we did above

# %% [markdown]
# Manually you can download the GCT Geographic Comparison Tables. Download the GCT table that contains the percentage of households in each PUMA with broadband internet subscription as follows:
#
# https://factfinder.census.gov/ -> Advanced Search -> Show me all
#
#     - Topics: Product Type -> Geography Comparison Table
#
# select the PERCENT OF HOUSEHOLDS WITH A BROADBAND INTERNET SUBSCRIPTION  at our geography granularity (PUMA) and click Download below. This will generate the table on the fly and you can click again on Download.
#
# Move the file into the PUIdata directory, unzip it and load it with pandas.
#
# Your table shold be labeled as: GCT2801

# %% [markdown]
# One more hurdle: you need to move this data to jupyterhub/compute, and the link is not something you can copy and paste!
# Two solutions:
#
# -easier but less preferible: upload the table you downloaded locally to github AWS, or else where, and download it from compute
#
# -otherwise, learn how to do it with sftp from your local terminal: these are the steps
#
# 1. ON YOUR LOCAL MACHINE where you downloaded the table (which was downloaded as aff_download.zip for me in my ~/Downloads folder) type the following *sftp* command
#
#         fbianco@Federicas-MacBook-Air:~$ sftp fbianco@staging.cusp.nyu.edu
#
# 2. Input your password
#
#         Password:
#         Connected to staging.cusp.nyu.edu.
#
#    This should open an sftp promopt (you should see sftp> at the beginning of the line). Go to the PUI directory (for me /home/fbianco/PUIdata)
#
#         sftp> cd /home/fbianco/PUIdata
#
# 3. Use the sftp command _put_ to copy the file from the local to the remote machine to compute, making sure you use the full path (unless the file was downloaded in your local directory in the local machine)
#
#         sftp> put /Users/fbianco/Downloads/aff_download.zip
#
# You should see:
#
#             Uploading /Users/fbianco/Downloads/aff_download.zip to ....
#
# And the file can be unzipped and read into your code with pandas. I leave the read in line below for your convenience, those are the only variables you need.

# %%
# !unzip $PUIDATA/ACS_17_1YR_GCT2801.ST50.zip -d $PUIDATA
# Out:
# Archive:  /nfshome/tp1600/PUIdata/ACS_17_1YR_GCT2801.ST50.zip
# replace /nfshome/tp1600/PUIdata/ACS_17_1YR_GCT2801.ST50_with_ann.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
bbpc = pd.read_csv(os.getenv("PUIDATA") + "/ACS_17_1YR_GCT2801.ST50_with_ann.csv",
            usecols=["GCT_STUB.target-geo-id2","HC01","HC02"])

bbpc.head()
# Out:
#   GCT_STUB.target-geo-id2     HC01             HC02
# 0          Target Geo Id2  Percent  Margin of Error
# 1                      01     78.1              0.5
# 2                 0100100     75.0              2.5
# 3                 0100200     84.0              2.4
# 4                 0100301     89.4              2.9

# %% [markdown]
# notice 2 things:
#     - that the Target Geo Id2: GCT_STUB.target-geo-id2 is a 7 digits number. See my comment above about it.
#     - that there is a weird double header. You can deal with it in one of 2 ways: either reread the file in skipping one row and using the second row as header, or remove that row (for example with bbpc.drop(0, inplace=True)) but also then you should check the *type* of your GCT_STUB.target-geo-id2 feature! The fact that pandas had to read in a column with nombers and characters forced it to read it as a string, and you need to convert it (.astype(int)) to merge it easily with the API acquired data.
#
# In the API dataframe the PUMA id was a 4 digit number. If you have them both as integers and you remove the initial three digits (for example by subtracting 360000 from each value wich you can do as bbpc["gid"] = bbpc.gid - 3600000 then you can merge on the puma id

# %%
bbpc.drop(0, inplace=True)
bbpc["HC01"].astype(float)
bbpc["HC02"].astype(float)
bbpc["GCT_STUB.target-geo-id2"].astype(int)

bbpc.head()
# Out:
#   GCT_STUB.target-geo-id2  HC01 HC02
# 1                      01  78.1  0.5
# 2                 0100100  75.0  2.5
# 3                 0100200  84.0  2.4
# 4                 0100301  89.4  2.9
# 5                 0100302  85.1  2.6

# %%
bbpc["gid"] = bbpc["GCT_STUB.target-geo-id2"].astype(int) - 3600000
bbpc.head()
# Out:
#   GCT_STUB.target-geo-id2  HC01 HC02      gid
# 1                      01  78.1  0.5 -3599999
# 2                 0100100  75.0  2.5 -3499900
# 3                 0100200  84.0  2.4 -3499800
# 4                 0100301  89.4  2.9 -3499699
# 5                 0100302  85.1  2.6 -3499698

# %% [markdown]
# ## check that the percentage of households with broadband you generated and the one you red in from the table you downloaded manually are the same

# %%
diff_ = pumaBBf.merge(bbpc, right_on="gid", 
                     left_on="public use microdata area")[["Percentage", "HC01"]]

diff_["HC01"]=diff_["HC01"].astype(float)
diff_["diff"] = np.abs(diff_["Percentage"] - diff_["HC01"].astype(float))

diff_.describe()

#diff_.head()
# Out:
#        Percentage        HC01        diff
# count  145.000000  145.000000  145.000000
# mean    81.845478   83.501379    2.698737
# std      7.063369    6.487070    2.258818
# min     54.932945   57.000000    0.033409
# 25%     77.770257   79.800000    0.994923
# 50%     82.826141   84.200000    2.143335
# 75%     87.305077   88.300000    3.701693
# max     93.404143   95.300000   11.689985

# %% [markdown]
# the maximum difference should only be a few percent
#
# The maximum difference here is 11.

# %% [markdown]
# # 3 Plot a choropleth of NYC broadband access
# ## 3.1 Merge with the puma geodataframe and plot a choropleth of the percentage of households with broadband access

# %%
pumashp.puma=pumashp.puma.astype(int)
pumashp=pumashp.merge(pumaBBf, right_on="public use microdata area", left_on="puma")
pumashp.head()
# Out:
#    puma    shape_area     shape_leng  \
# 0  3701  9.792852e+07   53227.144461
# 1  3702  1.889860e+08  106050.002302
# 2  3703  2.670137e+08  304071.257466
# 3  3704  1.062129e+08   47970.901277
# 4  4015  8.105438e+07   50007.415493
#
#                                             geometry  B28002_004E  \
# 0  POLYGON ((-73.89641133483133 40.90450452082026...        35529
# 1  POLYGON ((-73.8442314689986 40.86942035096838,...        34030
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...        36716
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...        32269
# 4  POLYGON ((-73.95374853778468 40.63858633758547...        44079
#
#                                                 NAME  state  \
# 0  NYC-Bronx Community District 8--Riverdale, Fie...     36
# 1  NYC-Bronx Community District 12--Wakefield, Wi...     36
# 2  NYC-Bronx Community District 10--Co-op City, P...     36
# 3  NYC-Bronx Community District 11--Pelham Parkwa...     36
# 4  NYC-Brooklyn Community District 14--Flatbush &...     36
#
#    public use microdata area  Unnamed: 4_x  B28002_001E  Percentage
# 0                       3701           NaN        42158   84.275820
# 1                       3702           NaN        49817   68.310015
# 2                       3703           NaN        44329   82.826141
# 3                       3704           NaN        44476   72.553737
# 4                       4015           NaN        55953   78.778618

# %%
#create a choropleth of the percentage of internet access
f, ax = plt.subplots(figsize=(10,10))
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
pumashp.plot(column='Percentage', cmap='viridis', alpha=1, lw=1, ax=ax, legend=True)

# %% [markdown]
# The figure above shows percentage of households with broadband access across NYC, plotted by puma. You can see that the LES of Manhattan has the lowest while neighboring Financial District & Battery Park are among the highest.

# %% [markdown]
# # 4. LinkNYC: assess whether the locations of the linkNYC stations are supplying internet where it is needed.
#
# acquire the linkNYC locations and prepare them into a dataframe
# read it in from the HW7_fb55 folder in :
# https://github.com/fedhere/PUI2018_fb55
#
# Notice that you can also get a linkNYC locations shapefile from NYC open data, as I did to generate this, but I want you do to do some extra coordinates gymnastics for practice so use the one I provide.

# %%
linkNYC=pd.read_csv("https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW7_fb55/linkNYClocations.csv", index_col=0)

# %%
linkNYC.head()
# Out:
#       link_site  longitude  date_link_   latitude
# 0  bk-01-138951 -73.942489  2017-07-01  40.701668
# 1  bk-01-109091 -73.942169  2017-07-01  40.701542
# 2  bk-01-143982 -73.942239  2017-07-01  40.701930
# 3  bk-01-109262 -73.942918  2017-04-28  40.705060
# 4  bk-01-125268 -73.953439  2017-03-31  40.728133

# %%
linkNYC.shape
# Out:
# (1414, 4)

# %% [markdown]
# ## combine long lat into a column like you did in the lab to greate a "geometry" column for the dataframe, then convert the dataframe into a GeoDataFrame _linkNYC_ and set native coordinates  frame to lat/lon as you did in the lab
#     linkNYC.crs = ...

# %%
linkNYC["lonlat"]=list(zip(linkNYC.longitude,linkNYC.latitude))
linkNYC["geometry"] = linkNYC[["lonlat"]].applymap(lambda x:shapely.geometry.Point(x))

# %%
linkNYC.head()
# Out:
#       link_site  longitude  date_link_   latitude  \
# 0  bk-01-138951 -73.942489  2017-07-01  40.701668
# 1  bk-01-109091 -73.942169  2017-07-01  40.701542
# 2  bk-01-143982 -73.942239  2017-07-01  40.701930
# 3  bk-01-109262 -73.942918  2017-04-28  40.705060
# 4  bk-01-125268 -73.953439  2017-03-31  40.728133
#
#                             lonlat                                  geometry
# 0      (-73.94248859, 40.70166753)          POINT (-73.94248859 40.70166753)
# 1  (-73.9421692831, 40.7015421938)      POINT (-73.9421692831 40.7015421938)
# 2  (-73.9422392385, 40.7019303439)  POINT (-73.94223923850001 40.7019303439)
# 3      (-73.94291758, 40.70506042)          POINT (-73.94291758 40.70506042)
# 4          (-73.953439, 40.728133)              POINT (-73.953439 40.728133)

# %%
linkNYC.head()
# Out:
#       link_site  longitude  date_link_   latitude  \
# 0  bk-01-138951 -73.942489  2017-07-01  40.701668
# 1  bk-01-109091 -73.942169  2017-07-01  40.701542
# 2  bk-01-143982 -73.942239  2017-07-01  40.701930
# 3  bk-01-109262 -73.942918  2017-04-28  40.705060
# 4  bk-01-125268 -73.953439  2017-03-31  40.728133
#
#                             lonlat                                  geometry
# 0      (-73.94248859, 40.70166753)          POINT (-73.94248859 40.70166753)
# 1  (-73.9421692831, 40.7015421938)      POINT (-73.9421692831 40.7015421938)
# 2  (-73.9422392385, 40.7019303439)  POINT (-73.94223923850001 40.7019303439)
# 3      (-73.94291758, 40.70506042)          POINT (-73.94291758 40.70506042)
# 4          (-73.953439, 40.728133)              POINT (-73.953439 40.728133)

# %%
#convert to a geodataframe
linkNYC=gpd.GeoDataFrame(linkNYC)

# %%
linkNYC.crs=from_epsg(4326)

# %% [markdown]
# # plot the location of the linkNYC stations on top of a choropleth of broadband access percentage in *5 equal intervals*
#
# I have also color coded the station by how long ago they have been installed, using the date datetime variable

# %%
f, ax = plt.subplots(figsize=(10,10))
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
pumashp.plot('Percentage', cmap='viridis', alpha=1, lw=1, ax=ax, legend=True, scheme="Equal_interval", k=5)
linkNYC.plot('lonlat', color='black', alpha=.5, lw=.5, ax=ax)
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/geopandas/plotting.py:389: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   "'color'.", UserWarning)

# %% [markdown]
# The figure above shows the map of broadband on color and the map of Link stations as black dots.

# %% [markdown]
# # 5 Find the number of linkNYC locations per person by PUMA
#
# ## 5.1 with the AFF API from ACS get the total population by puma and merge it into your GeoDF

# %% [markdown]
# the ACS population by  variable is B00001_001E, and of course your geometry is PUMA, _public%20use%20microdata%20area:*_, as before

# %%
keyPOP='B00001_001E'
url = "https://api.census.gov/data/2016/acs/acs1?get=" + keyPOP +\
",NAME&for=public%20use%20microdata%20area:*&in=state:36&key=" + myAPI
resp = requests.request('GET', url).content
pumapop = pd.read_csv(io.StringIO(resp.decode('utf-8').replace('[','').replace(']','')))

# %%
pumapop.head()
# Out:
#    B00001_001E                                               NAME  state  \
# 0         3075                 St. Lawrence County PUMA, New York     36
# 1         4356  Clinton, Franklin, Essex & Hamilton Counties P...     36
# 2         2736        Warren & Washington Counties PUMA, New York     36
# 3         2722  Herkimer (North & Central) & Oneida (Outer) Co...     36
# 4         2874  Oneida County (Central)--Greater Utica & Rome ...     36
#
#    public use microdata area  Unnamed: 4
# 0                        100         NaN
# 1                        200         NaN
# 2                        300         NaN
# 3                        401         NaN
# 4                        402         NaN

# %%
#pumaPop.head()

# %%
pumashp.head()
# Out:
#    puma    shape_area     shape_leng  \
# 0  3701  9.792852e+07   53227.144461
# 1  3702  1.889860e+08  106050.002302
# 2  3703  2.670137e+08  304071.257466
# 3  3704  1.062129e+08   47970.901277
# 4  4015  8.105438e+07   50007.415493
#
#                                             geometry  B28002_004E  \
# 0  POLYGON ((-73.89641133483133 40.90450452082026...        35529
# 1  POLYGON ((-73.8442314689986 40.86942035096838,...        34030
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...        36716
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...        32269
# 4  POLYGON ((-73.95374853778468 40.63858633758547...        44079
#
#                                                 NAME  state  \
# 0  NYC-Bronx Community District 8--Riverdale, Fie...     36
# 1  NYC-Bronx Community District 12--Wakefield, Wi...     36
# 2  NYC-Bronx Community District 10--Co-op City, P...     36
# 3  NYC-Bronx Community District 11--Pelham Parkwa...     36
# 4  NYC-Brooklyn Community District 14--Flatbush &...     36
#
#    public use microdata area  Unnamed: 4_x  B28002_001E  Percentage
# 0                       3701           NaN        42158   84.275820
# 1                       3702           NaN        49817   68.310015
# 2                       3703           NaN        44329   82.826141
# 3                       3704           NaN        44476   72.553737
# 4                       4015           NaN        55953   78.778618

# %%
pumashp=pumashp.merge(pumapop[['B00001_001E',"public use microdata area"]], right_on="public use microdata area", left_on="puma")

# %% [markdown]
# ## 5.2 find the number of station per 100 people per PUMA
# **Important** you can do this with an sjoin(). But sjoin() should not be used with lat/lon coordinates cause they are **not "flat coordinates"**. Since spattial joins are done in cartesian geometry the only coordinate systems suitable to spatial joins are flat coordinate plane systems, which in the NYC area is 2263. So before you proceed to the sjoin you have to convert both pumashp and linkNYC to 2263 (for example with GeoDataFrame method .to_crs(epsg=...) )
#
#
# (A note: You can also do this by hand by asking for each point if it is in any of the regions, for example in a for loop. But that is escruciatingly slow, unless you get smart about your requests (for example for a given PUMA not asking if the coordinates of a point are very different from the center of a PUMA). With the new version of geopandas this is not needed, cause the sjoin is fast, but with the older versions this was sometimes better) )

# %% [markdown]
# convert coordinates for pumashp and linkNYC

# %%
pumashp.crs
# Out:
# {'init': 'epsg:4326'}

# %%
pumashpcv=pumashp.to_crs(epsg=2263)

# %%
linkNYC.crs
# Out:
# {'init': 'epsg:4326', 'no_defs': True}

# %%
linkNYCcv=linkNYC.to_crs(epsg=2263)

# %% [markdown]
# create a geodataframe with a spatial join and use groupby to count the number of linkNYC in each PUMA

# %%
gpd.sjoin?

# %%
linkpp=gpd.sjoin(pumashpcv, linkNYCcv, how='inner').groupby('puma').count()

# %%
linkpp=linkpp[['link_site']]
linkpp.head()
# Out:
#       link_site
# puma
# 3701          1
# 3705          1
# 3706         20
# 3707         29
# 3708         19

# %% [markdown]
# finally merge back into the pumashp. Make sure you use the correct scheme for merging: you want to have _all_ the PUMAs, not only the ones that have linkNYC in them in the final geoDF

# %%
pumashp=pumashp.merge(linkpp, right_index=True, left_on='puma', how='left')
pumashp.head()
# Out:
#    puma    shape_area     shape_leng  \
# 0  3701  9.792852e+07   53227.144461
# 1  3702  1.889860e+08  106050.002302
# 2  3703  2.670137e+08  304071.257466
# 3  3704  1.062129e+08   47970.901277
# 4  4015  8.105438e+07   50007.415493
#
#                                             geometry  B28002_004E  \
# 0  POLYGON ((-73.89641133483133 40.90450452082026...        35529
# 1  POLYGON ((-73.8442314689986 40.86942035096838,...        34030
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...        36716
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...        32269
# 4  POLYGON ((-73.95374853778468 40.63858633758547...        44079
#
#                                                 NAME  state  \
# 0  NYC-Bronx Community District 8--Riverdale, Fie...     36
# 1  NYC-Bronx Community District 12--Wakefield, Wi...     36
# 2  NYC-Bronx Community District 10--Co-op City, P...     36
# 3  NYC-Bronx Community District 11--Pelham Parkwa...     36
# 4  NYC-Brooklyn Community District 14--Flatbush &...     36
#
#    public use microdata area_x  Unnamed: 4_x  B28002_001E  Percentage  \
# 0                         3701           NaN        42158   84.275820
# 1                         3702           NaN        49817   68.310015
# 2                         3703           NaN        44329   82.826141
# 3                         3704           NaN        44476   72.553737
# 4                         4015           NaN        55953   78.778618
#
#    B00001_001E  public use microdata area_y  link_site
# 0         1517                         3701        1.0
# 1         1959                         3702        NaN
# 2         1305                         3703        NaN
# 3         1882                         3704        NaN
# 4         2515                         4015        3.0

# %%
pumashp.columns
# Out:
# Index(['puma', 'shape_area', 'shape_leng', 'geometry', 'B28002_004E', 'NAME',
#        'state', 'public use microdata area_x', 'Unnamed: 4_x', 'B28002_001E',
#        'Percentage', 'B00001_001E', 'public use microdata area_y',
#        'link_site'],
#       dtype='object')

# %%
pumashp['pumashplc']=pumashp['link_site']/(pumashp['B00001_001E']/100)
pumashp['pumashplc'].describe()
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/numpy/lib/function_base.py:3403: RuntimeWarning: Invalid value encountered in median
#   RuntimeWarning)
# count    37.000000
# mean      2.327677
# std       3.328955
# min       0.049727
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max      15.141540
# Name: pumashplc, dtype: float64

# %%
#linkNYC per 100 inhabitants
#pumashplc["linkNYCp100p"].describe()

# %% [markdown]
# # at last, plot the linkNYC locations on top of a choropleth of number of stations per 100 people  in 10 equal intervals

# %%
f, ax = plt.subplots(figsize=(10,10))
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
pumashp.plot('pumashplc', cmap='viridis', alpha=1, lw=1, ax=ax, legend=True, scheme="Equal_interval", k=10)
linkNYC.plot('lonlat', color='red', alpha=.2, lw=.1, ax=ax)
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/numpy/lib/function_base.py:3142: RuntimeWarning: Invalid value encountered in median
#   RuntimeWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/geopandas/plotting.py:389: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   "'color'.", UserWarning)

# %% [markdown]
# The figure above shows link stations by 100 people in population by PUMA area, as well as the link stations.

# %% [markdown]
# # Extra credit 1:
# How would you enhance the visibility of this map? you are working with numbers that are mostly very low, and reside near each other, and them have a few much higher value points. Notice that here the high values are interesting though and should not be thrown away!

# %%
#pl.hist(pumashp["pumashplc"], bins=30);

# %% [markdown]
# ## I would define the highest two intevalas as 6-8 and 8+, allowing the other interval buckets to be show more granular detail.

# %% [markdown]
# ## Extra Credit 2:
# plot Spatial Lag Deciles that describe the impact of linkNYC in providing access where needed. You can follow what you did in the lab, but you need to create a metric based on the data you have tha measures the impact of linkNYC

# %% [markdown]
# this is whay I came up with, and needs not be the same for you. But properly describe what you obtain

# %% [markdown]
# Note: To find the table you extracted through the API manually you could
#
# https://factfinder.census.gov/ -> Advanced Search -> Show me all
#
#     - Topics: Housing -> Physical Characteristics -> Internet Access
#     - Geographies -> all geography types -> Public Use Microdata Areas (755)
#                      -> Select a State: New York -> All Pubic Use Microdaa Areas within New York
#                      -> Add Your Selection
#     - Years -> 2016
